# %% [markdown]
# ## Why scrape a site?
#
# - get needed info
# - faster than manually recording information
# - it's fun!

# %% [markdown]
# ## Personal Examples
#
# - [Remember the Milk - online task list](https://rememberthemilk.com)
# - [Overcast podcast player website](https://overcast.fm)
# - [Audible](https://audible.com)
# - [Datacamp](https://datacamp.com)
# - [O'Reilly Safari Online](https://learning.oreilly.com/videos/jupytercon-2017/9781491985311)

# %% [markdown]
# # How to get started?
#
# ## Tools
# - Python (obviously)
# - Beautiful Soup - https://www.crummy.com/software/BeautifulSoup/
# - Requests - http://docs.python-requests.org/en/master/

# %% [markdown]
# # install with pip
#
# ```python
# pip install beautifulsoup4
# pip install requests
# ```
#
# ## or just use anaconda...
# - both are included by default

# %% [markdown]
# ## start with Beautiful Soup first
# - go to the site you want to scrape
# - save page as
# - open in your favorite text editor
# - start exploring!

# %% [markdown]
# ## Some simple HTML
# - combination of [W3 Schools](https://www.w3schools.com/html/html_intro.asp) and the [BeautifulSoup documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %%
html_stuff = """<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
</head>
<body>

<h1>My First Heading</h1>
<p>My first paragraph.</p>
<h1>My Second Heading</h1>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
</body>
</html>"""

# %%
from bs4 import BeautifulSoup

# create soup object - pass the html and which parser to use
soup = BeautifulSoup(html_stuff, 'html.parser')

# %% [markdown]
# - note that there are other parsers supported (check the documentation) but that is outside the scope of this talk
# - the standard html parser works fine for our purposes

# %% [markdown]
# ### Beatiful soup will show us the nested structure of the soup object

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h1>
#    My First Heading
#   </h1>
#   <p>
#    My first paragraph.
#   </p>
#   <h1>
#    My Second Heading
#   </h1>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## We can pull out specific elements

# %%
soup.title
# Out:
# <title>Page Title</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.parent.name
# Out:
# 'head'

# %% [markdown]
# # Common tasks - pulling text and URLs

# %% [markdown]
# ### Use find_all() or find()

# %%
soup.find_all('h1')
# Out:
# [<h1>My First Heading</h1>, <h1>My Second Heading</h1>]

# %% [markdown]
# #### Find() is useful if there is only one of that tag so that the parser does not have to search the entire document

# %%
soup.find('h1')
# Out:
# <h1>My First Heading</h1>

# %% [markdown]
# ### Return only the text

# %%
print(soup.get_text())
# Out:
# Page Title
#
#
# My First Heading
# My first paragraph.
# My Second Heading
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.

# %% [markdown]
# ### Just the URLs

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# ### Just the text from a specific tag

# %%
for text in soup.find_all('a'):
    print(text.get_text())
# Out:
# Elsie
# Lacie
# Tillie

# %%
for text in soup.find_all('h1'):
    print(text.get_text())
# Out:
# My First Heading
# My Second Heading

# %% [markdown]
# # Real World Example

# %%
with open('Think Stats, 2nd Edition.html', 'r') as out:
    safari = out.read()
    
safari_soup = BeautifulSoup(safari, 'html.parser')

# %%
print(safari_soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0072)https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ -->
# <html class=" js flexbox flexboxlegacy no-touch websqldatabase indexeddb history csscolumns csstransforms localstorage sessionstorage applicationcache svg inlinesvg" data-account-type="Paid" data-activated-trial-date="09/12/2017" data-archive="9781491907344" data-book-overview="true" data-csrf-cookie="csrfsafari" data-debug="0" data-highlight-privacy="" data-login-url="/accounts/login/" data-offline-url="/" data-publishers="O'Reilly Media, Inc." data-testing="0" data-url="/library/view/think-stats-2nd/9781491907344/" data-user-id="2002766" data-user-uuid="0f245ad9-c9d7-4f63-95c5-def519b24116" data-username="jballoonist" itemscope="" itemtype="http://schema.org/Book http://schema.org/CollectionPage" lang="en" prefix="og: http://ogp.me/ns/# og:book: http://ogp.me/ns/book# og:video: http://ogp.me/ns/video#" style="">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Think Stats, 2nd Edition
#   </title>
#   <meta content="If you know how to program, you have the skills to turn data into knowledge, using tools of probability and statistics. This concise introduction shows you h..." name="description"/>
#   <link href="https://www.oreilly.com/favicon.ico" rel="shortcut icon"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Safari Books Online" name="author"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="app-id=881697395, app-argument=safaridetail://9781491907344" name="apple-itunes-app"/>
#   <meta content="width=device-width, minimum-scale=1.0, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="4503599627559754" property="twitter:account_id"/>
#   <script async="" src="./Think Stats, 2nd Edition_files/cool-2.1.15.min.js.download" type="text/javascript">
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/510f1a6865" type="text/javascript">
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/nr-1118.min.js.download">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/munchkin.js.download" type="text/javascript">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/1732687426968531">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/fbevents.js.download">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/bat.js.download" type="text/javascript">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/f.txt" type="text/javascript">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/f.txt" type="text/javascript">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/linkid.js.download" type="text/javascript">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/gtm.js.download">
#   </script>
#   <script async="" src="./Think Stats, 2nd Edition_files/analytics.js.download">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&&e.applicationID&&n))return s.abort();c(y,function(n,t){e[n]||(e[n]=t)}),f("mark",["onload ...
#   </script>
#   <link href="https://learning.oreilly.com/static/images/apple-touch-icon.0c29511d2d72.png" rel="apple-touch-icon"/>
#   <link href="https://learning.oreilly.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="./Think Stats, 2nd Edition_files/css" rel="stylesheet" type="text/css"/>
#   <link href="./Think Stats, 2nd Edition_files/55b529c307e8.css" rel="stylesheet" type="text/css"/>
#   <link href="./Think Stats, 2nd Edition_files/cf849c3e47ca.css" rel="stylesheet" type="text/css"/>
#   <link href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/" rel="canonical"/>
#   <meta content="Think Stats, 2nd Edition" property="og:title"/>
#   <meta content="Think Stats, 2nd Edition" itemprop="name"/>
#   <meta content="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/" itemprop="url" property="og:url"/>
#   <meta content="Safari" property="og:site_name"/>
#   <meta content="https://learning.oreilly.com/library/cover/9781491907344/" itemprop="thumbnailUrl" property="og:image"/>
#   <meta content="If you know how to program, you have the skills to turn data into knowledge, using tools of probability and statistics. This concise introduction shows you how to perform statistical ... " itemprop="description" property="og:description"/>
#   <meta content="en" itemprop="inLanguage"/>
#   <meta content="O'Reilly Media, Inc." itemprop="publisher"/>
#   <meta content="book" property="og:type"/>
#   <meta content="9781491907337" itemprop="isbn" property="og:book:isbn"/>
#   <meta content="Allen B. Downey" itemprop="author" property="og:book:author"/>
#   <meta content="Math &amp; Science" itemprop="about" property="og:book:tag"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@safari" name="twitter:site"/>
#   <!--[if lt IE 9]><script src="/static/js/src/respond.min.3b44ce04a146.js"></script><![endif]-->
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m) {
#       i['GoogleAnalyticsObject']=r;
#       i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();
#       a=s.createElement(o),m=s.getElementsByTagName(o)[0];
#       a.async=1;
#       a.src=g;
#       m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     var matches = document.cookie.match(/BrowserCookie\s*=\s*([a-f0-9\-]{36})/),
#       user_uuid = null;
#
#     if (matches && matches.length === 2) {
#       user_uuid = matches[1];
#     }
#
#
#     ga('create', 'UA-39299553-7', {'userId': '0f245ad9-c9d7-4f63-95c5-def519b24116' });
#
#
#
#
#       ga('set', 'dimension1', 'Paid');
#
#
#
#   ga('set', 'dimension6', user_uuid);
#
#
#     ga('set', 'dimension2', '0f245ad9-c9d7-4f63-95c5-def519b24116');
#
#
#
#
#
#
#
#   //enable enhanced link tracking
#   ga('require', 'linkid', 'linkid.js');
#
#   // reading interface will track pageviews itself
#   if (document.location.pathname.indexOf("/library/view") !== 0) {
#     ga('send', 'pageview');
#   }
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-5P4V6Z');
#   </script>
#   <script charset="utf-8" defer="" src="./Think Stats, 2nd Edition_files/saved_resource">
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/modernizr.8e35451ddb64.js.download">
#   </script>
#   <script>
#    var g = {};
#
#
#       window.SBO = {
#         "constants": {
#           "SEARCH_ENDPOINT": "/api/v2/search/",
#           "SEARCH_SELECT_ENDPOINT": "/api/v2/search/select/",
#           "SUGGEST_ENDPOINT": "/api/v1/search/suggest/",
#           "REVIEWS_ENDPOINT": "/api/v1/reviews/",
#           "REPORTS_ENDPOINT": "/api/v1/reports/",
#           "REPORTS_BATCH_ENDPOINT": "/api/v1/reports/batch/",
#           "ACADEMIC_INSTITUTION_ACCOUNT": "false",
#           "ENABLE_ONLINE_TRAINING": true,
#           "SELF_ASSESSMENT_SWITCH": "true"
#         }
#       };
#
#         window.CURRENT_SITE = "www.safaribooksonline.com" || "www.safaribooksonline.com";
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/remove-dup-cookies.3b1f381d4a59.js.download">
#   </script>
#   <script>
#    ga('send', 'pageview');
#   window.queued = JSON.parse('[]');
#   </script>
#   <script defer="" src="./Think Stats, 2nd Edition_files/vendor.860721dad816.js.download">
#   </script>
#   <script defer="" src="./Think Stats, 2nd Edition_files/detailPage.3573d9f3670b.js.download">
#   </script>
#   <!-- Start Visual Website Optimizer Asynchronous Code -->
#   <script type="text/javascript">
#    var _vwo_code=(function(){
# var account_id=291788,
# settings_tolerance=2000,
# library_tolerance=2500,
# use_existing_jquery=false,
# /* DO NOT EDIT BELOW THIS LINE */
# f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());_vwo_settings_timer=_vwo_code.init();
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/j.php" type="text/javascript">
#   </script>
#   <!-- End Visual Website Optimizer Asynchronous Code -->
#   <script async="" src="./Think Stats, 2nd Edition_files/munchkin.js(1).download" type="text/javascript">
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/f(1).txt">
#   </script>
#   <script src="./Think Stats, 2nd Edition_files/f(2).txt">
#   </script>
#   <style id="kampyleStyle" type="text/css">
#    .noOutline{outline: none !important;}.wcagOutline:focus{outline: 1px dashed #595959 !important;outline-offset: 2px !important;transition: none !important;}
#   </style>
#   <link href="chrome-extension://jjklfihngajdehchifejpbepdgbbejml/webapp/chrome/contentscript.css" rel="stylesheet" type="text/css"/>
#   <link href="chrome-extension://jjklfihngajdehchifejpbepdgbbejml/webapp/chrome/contentscript.css" rel="stylesheet" type="text/css"/>
#   <link href="chrome-extension://jjklfihngajdehchifejpbepdgbbejml/webapp/chrome/Module/status.css" rel="stylesheet" type="text/css"/>
#   <link href="chrome-extension://jjklfihngajdehchifejpbepdgbbejml/webapp/chrome/Module/messages.css" rel="stylesheet" type="text/css"/>
#   <link href="chrome-extension://jjklfihngajdehchifejpbepdgbbejml/scripts/webfont.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="sidenav nav-collapsed bg js-heron tutorials-feature " style="">
#   <div class="rating-wrapper" id="js-ratings-modal-region">
#    <!-- Ratings modal rendered here via js -->
#   </div>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5P4V6Z" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <a class="orm-topbar" href="https://www.oreilly.com/" tabindex="1">
#    <svg height="13" viewbox="0 0 60 10" width="78" xmlns="http://www.w3.org/2000/svg">
#     <desc>
#      O'Reilly logo
#     </desc>
#     <polygon points="28.09 1.96 28.09 0.42 21.68 0.42 21.68 9.64 28.09 9.64 28.09 8.11 23.22 8.11 23.22 5.8 27.86 5.8 27.86 4.27 23.22 4.27 23.22 1.96 28.09 1.96">
#     </polygon>
#     <polygon points="32.85 9.64 32.85 0.42 34.39 0.42 34.39 8.11 38.82 8.11 38.82 9.64 32.85 9.64">
#     </polygon>
#     <polygon points="40.07 9.64 40.07 0.42 41.61 0.42 41.61 8.11 46.04 8.11 46.04 9.64 40.07 9.64">
#     </polygon>
#     <rect height="9.22" width="1.54" x="29.71" y="0.42">
#     </rect>
#     <path d="M1.59,6.28a4.8,4.8,0,1,1,4.8,4.8,4.8,4.8,0,0,1-4.8-4.8M4.09,4A3.27,3.27,0,1,0,6.4,3,3.27,3.27,0,0,0,4.09,4" transform="translate(-1.59 -1.2)">
#     </path>
#     <path d="M19.82,6.89A2.69,2.69,0,0,0,19,1.62H14.41v9.22h1.54V7h2.14l2.32,3.84H22.2ZM15.95,5.47V3.16H19a1.15,1.15,0,0,1,0,2.31h-3.1Z" transform="translate(-1.59 -1.2)">
#     </path>
#     <path d="M13.32,2.61a1.13,1.13,0,1,1-1.13-1.13,1.13,1.13,0,0,1,1.13,1.13" transform="translate(-1.59 -1.2)">
#     </path>
#     <polygon points="52.9 0.42 51.03 0.42 48.66 3.85 46.3 0.42 44.43 0.42 47.89 5.44 47.89 9.64 49.43 9.64 49.43 5.44 52.9 0.42">
#     </polygon>
#     <path d="M58.31,1.2a2.41,2.41,0,1,0,2.41,2.42A2.42,2.42,0,0,0,58.31,1.2m0,4.44a2,2,0,1,1,2-2,2,2,0,0,1-2,2" transform="translate(-1.59 -1.2)">
#     </path>
#     <path d="M59.4,3.09a0.72,0.72,0,0,0-.72-0.72H57.32V4.83h0.41v-1h0.69l0.49,1h0.46l-0.51-1a0.71,0.71,0,0,0,.54-0.69m-1.67-.31h0.95a0.31,0.31,0,0,1,.31.31,0.31,0.31,0,0,1-.31.3H57.73V2.78Z" transform="translate(-1.59 -1.2)">
#     </path>
#    </svg>
#   </a>
#   <a class="skip" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#container" tabindex="2">
#    Skip to content
#   </a>
#   <header class="topbar t-topbar">
#    <nav class="js-site-nav" role="navigation">
#     <ul class="topnav">
#      <li class="t-logo">
#       <a class="l0 None safari-home nav-icn js-keyboard-nav-home" href="https://learning.oreilly.com/home/" tabindex="3">
#        <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#         <desc>
#          Safari Home Icon
#         </desc>
#         <g fill-rule="evenodd" stroke="none" stroke-width="1">
#          <path d="M4 9.9L4 9.9 4 18 16 18 16 9.9 10 4 4 9.9ZM2.6 8.1L2.6 8.1 8.7 1.9 10 0.5 11.3 1.9 17.4 8.1 18 8.7 18 9.5 18 18.1 18 20 16.1 20 3.9 20 2 20 2 18.1 2 9.5 2 8.7 2.6 8.1Z">
#          </path>
#          <rect height="7" width="3" x="10" y="12">
#          </rect>
#          <rect height="2" transform="translate(18.121320, 10.121320) rotate(-315.000000) translate(-18.121320, -10.121320) " width="4" x="16.1" y="9.1">
#          </rect>
#          <rect height="2" transform="translate(2.121320, 10.121320) scale(-1, 1) rotate(-315.000000) translate(-2.121320, -10.121320) " width="4" x="0.1" y="9.1">
#          </rect>
#         </g>
#        </svg>
#        <span>
#         Safari Home
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="t-recommendations-nav l0 nav-icn None" href="https://learning.oreilly.com/r/" tabindex="4">
#        <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 50" width="20" xmlns="http://www.w3.org/2000/svg">
#         <desc>
#          recommendations icon
#         </desc>
#         <g fill-rule="evenodd" stroke="none" stroke-width="1">
#          <path d="M50 25C50 18.2 44.9 12.5 38.3 11.7 37.5 5.1 31.8 0 25 0 18.2 0 12.5 5.1 11.7 11.7 5.1 12.5 0 18.2 0 25 0 31.8 5.1 37.5 11.7 38.3 12.5 44.9 18.2 50 25 50 31.8 50 37.5 44.9 38.3 38.3 44.9 37.5 50 31.8 50 25ZM25 3.1C29.7 3.1 33.6 6.9 34.4 11.8 30.4 12.4 26.9 15.1 25 18.8 23.1 15.1 19.6 12.4 15.6 11.8 16.4 6.9 20.3 3.1 25 3.1ZM34.4 15.6C33.6 19.3 30.7 22.2 27.1 22.9 27.8 19.2 30.7 16.3 34.4 15.6ZM22.9 22.9C19.2 22.2 16.3 19.3 15.6 15.6 19.3 16.3 22.2 19.2 22.9 22.9ZM3.1 25C3.1 20.3 6.9 16.4 11.8 15.6 12.4 19.6 15.1 23.1 18.8 25 15.1 26.9 12.4 30.4 11.8 34.4 6.9 33.6 3.1 29.7 3.1 25ZM22.9 27.1C22.2 30.7 19.3 33.6 15.6 34.4 16.3 30.7 19.2 27.8 22.9 27.1ZM25 46.9C20.3 46.9 16.4 43.1 15.6 38.2 19.6 37.6 23.1 34.9 25 31.3 26.9 34.9 30.4 37.6 34.4 38.2 33.6 43.1 29.7 46.9 25 46.9ZM27.1 27.1C30.7 27.8 33.6 30.7 34.4 34.4 30.7 33.6 27.8 30.7 27.1 27.1ZM38.2 34.4C37.6 30.4 34.9 26.9 31.3 25 34.9 23.1 37.6 19.6 38.2 15.6 43.1 16.4 46.9 20.3 46.9 25 46.9 29.7 43.1 33.6 38.2 34.4Z">
#          </path>
#         </g>
#        </svg>
#        <span>
#         Recommended
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="t-queue-nav l0 nav-icn None" href="https://learning.oreilly.com/playlists/" tabindex="5">
#        <!--?xml version="1.0" encoding="UTF-8"?-->
#        <svg height="17px" version="1.1" viewbox="0 0 21 17" width="21px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <!-- Generator: Sketch 46.2 (44496) - http://www.bohemiancoding.com/sketch -->
#         <title>
#          icon_Playlist_sml
#         </title>
#         <desc>
#          Created with Sketch.
#         </desc>
#         <defs>
#         </defs>
#         <g fill="none" fill-rule="evenodd" id="Page-1" stroke="none" stroke-width="1">
#          <g fill="#000000" fill-rule="nonzero" id="icon_Playlist_sml">
#           <g id="playlist-icon">
#            <g id="Group-6">
#             <rect height="3" id="Rectangle-path" rx="0.5" width="16" x="5" y="0">
#             </rect>
#             <circle cx="1.5" cy="1.5" id="Oval" r="1.5">
#             </circle>
#            </g>
#            <g id="Group-5" transform="translate(0.000000, 7.000000)">
#             <circle cx="1.5" cy="1.5" id="Oval" r="1.5">
#             </circle>
#             <rect height="3" id="Rectangle-path" rx="0.5" width="16" x="5" y="0">
#             </rect>
#            </g>
#            <g id="Group-5-Copy" transform="translate(0.000000, 14.000000)">
#             <circle cx="1.5" cy="1.5" id="Oval" r="1.5">
#             </circle>
#             <rect height="3" id="Rectangle-path" rx="0.5" width="16" x="5" y="0">
#             </rect>
#            </g>
#           </g>
#          </g>
#         </g>
#        </svg>
#        <span>
#         Playlists
#        </span>
#       </a>
#      </li>
#      <li class="search">
#       <a class="t-search-nav trigger nav-icn l0" data-dropdown-selector=".searchbox" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#" tabindex="6">
#        <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 50" width="20" xmlns="http://www.w3.org/2000/svg">
#         <desc>
#          search icon
#         </desc>
#         <g fill-rule="evenodd" stroke="none" stroke-width="1">
#          <path d="M31.3 0C20.9 0 12.5 8.4 12.5 18.8 12.5 22.5 13.6 25.9 15.4 28.8L1.2 42.9C-0.4 44.5-0.4 47.2 1.2 48.8 2 49.6 3.1 50 4.2 50 5.2 50 6.3 49.6 7.1 48.8L21.2 34.6C24.1 36.5 27.5 37.5 31.3 37.5 41.6 37.5 50 29.1 50 18.8 50 8.4 41.6 0 31.3 0ZM31.3 31.3C24.4 31.3 18.8 25.6 18.8 18.8 18.8 11.9 24.4 6.3 31.3 6.3 38.1 6.3 43.8 11.9 43.8 18.8 43.8 25.6 38.1 31.3 31.3 31.3Z">
#          </path>
#         </g>
#        </svg>
#        <span>
#         Search
#        </span>
#       </a>
#      </li>
#      <li class="usermenu dropdown">
#       <a class="trigger l0 nav-icn nav-dropdown" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#" tabindex="7">
#        <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#         <desc>
#          navigation arrow
#         </desc>
#         <g fill-rule="evenodd" stroke="none" stroke-width="1">
#          <path d="M0.1 12.5L9.7 3.1C9.8 3 9.9 3 10 3 10.1 3 10.2 3 10.3 3.1L19.9 12.5C20 12.5 20 12.6 20 12.8 20 12.9 20 13 19.9 13L17 15.9C16.9 16 16.8 16 16.7 16 16.5 16 16.4 16 16.4 15.9L10 9.7 3.6 15.9C3.6 16 3.5 16 3.3 16 3.2 16 3.1 16 3 15.9L0.1 13C0 12.9 0 12.8 0 12.7 0 12.7 0 12.6 0.1 12.5Z">
#          </path>
#         </g>
#        </svg>
#        <span>
#         Expand Nav
#        </span>
#       </a>
#       <div class="drop-content">
#        <ul>
#         <li>
#          <a class="t-recent-nav l1 nav-icn None" href="https://learning.oreilly.com/history/" tabindex="8">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 50" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             recent items icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M25 0C11.2 0 0 11.2 0 25 0 38.8 11.2 50 25 50 38.8 50 50 38.8 50 25 50 11.2 38.8 0 25 0ZM6.3 25C6.3 14.6 14.6 6.3 25 6.3 35.4 6.3 43.8 14.6 43.8 25 43.8 35.4 35.4 43.8 25 43.8 14.6 43.8 6.3 35.4 6.3 25ZM31.8 31.5C32.5 30.5 32.4 29.2 31.6 28.3L27.1 23.8 27.1 12.8C27.1 11.5 26.2 10.4 25 10.4 23.9 10.4 22.9 11.5 22.9 12.8L22.9 25.7 28.8 31.7C29.2 32.1 29.7 32.3 30.2 32.3 30.8 32.3 31.3 32 31.8 31.5Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            History
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="t-topics-link l1 nav-icn None" href="https://learning.oreilly.com/topics" tabindex="9">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 55" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             topics icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M25 55L50 41.262 50 13.762 25 0 0 13.762 0 41.262 25 55ZM8.333 37.032L8.333 17.968 25 8.462 41.667 17.968 41.667 37.032 25 46.538 8.333 37.032Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Topics
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="l1 nav-icn t-learningpaths-nav js-toggle-menu-item" href="https://learning.oreilly.com/learning-paths/" tabindex="10">
#           <!--?xml version="1.0" encoding="UTF-8"?-->
#           <svg height="32px" version="1.1" viewbox="0 0 32 32" width="32px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#            <!-- Generator: Sketch 52.5 (67469) - http://www.bohemiancoding.com/sketch -->
#            <title>
#             Mask
#            </title>
#            <desc>
#             Created with Sketch.
#            </desc>
#            <g fill="none" fill-rule="evenodd" id="Page-1" stroke="none" stroke-width="1">
#             <path d="M0,16.0214227 C0,15.0387209 0.796453294,14.2411658 1.77779753,14.2411658 C2.75914177,14.2411658 3.55559506,15.0387209 3.55559506,16.0214227 C3.55559506,17.0041246 2.75914177,17.8016797 1.77779753,17.8016797 C0.796453294,17.8016797 0,17.0041246 0,16.0214227 Z M9.77788642,5.22914885 C8.9280992,5.72049977 7.84008711,5.42853763 7.34941499,4.57757479 C6.85874287,3.72661195 7.15030167,2.63709467 8.00008889,2.14574375 C8.84987611,1.65439282 9.9378882,1.94635496 10.4285603,2.7973178 C10.9192324,3.64828064 10.6276736,4.73779792 9.77788642,5.22914885 Z M4.57213969,7.35869225 C5.42192691,7.85004318 5.71348571,8.93956046 5.22281359,9.79052329 C4.73214147,10.6414861 3.64412938,10.9334483 2.79434216,10.4420974 C1.94455494,9.95074642 1.65299614,8.86122915 2.14366826,8.01026631 C2.63434038,7.15930347 3.72235247,6.86734132 4.57213969,7.35869225 Z M2.79434216,21.6007481 C3.64412938,21.1093972 4.73214147,21.4013594 5.22281359,22.2523222 C5.71348571,23.103285 5.42192691,24.1928023 4.57213969,24.6841532 C3.72235247,25.1755042 2.63434038,24.883542 2.14366826,24.0325792 C1.65299614,23.1816163 1.94455494,22.0920991 2.79434216,21.6007481 Z M7.34941499,27.4652707 C7.84008711,26.6143079 8.9280992,26.3223457 9.77788642,26.8136966 C10.6276736,27.3050476 10.9192324,28.3945649 10.4285603,29.2455277 C9.9378882,30.0964905 8.84987611,30.3884527 8.00008889,29.8971017 C7.15030167,29.4057508 6.85874287,28.3162335 7.34941499,27.4652707 Z M18.7118524,11.3165596 C21.3074367,12.8173162 22.1963355,16.1392758 20.6976522,18.738451 C19.1989689,21.3358459 15.8815987,22.2259744 13.2860143,20.726998 C10.6922077,19.2262414 9.80330893,15.9042818 11.3002144,13.3051066 C12.7988978,10.7059314 16.116268,9.81580294 18.7118524,11.3165596 Z M26.7821642,27.8093944 L30.1315348,31.1633985 C30.3982044,31.4304371 30.2097579,31.8844026 29.8346426,31.8844026 L21.5945511,31.8844026 C21.1287681,31.8844026 20.751875,31.5069881 20.751875,31.0405608 L20.751875,22.7890697 C20.751875,22.4134355 21.2052134,22.2247282 21.4701052,22.4899865 L24.2843587,25.3081333 C26.8337204,23.0240636 28.4444049,19.7092251 28.4444049,16.0223129 C28.4444049,9.15052091 22.8621207,3.56051397 15.9998222,3.56051397 L15.9998222,0 C24.8230314,0 32,7.18689745 32,16.0223129 C32,20.6919269 29.9750886,24.8790914 26.7821642,27.8093944 Z" fill="#8B889A" id="Mask">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Learning Paths
#           </span>
#          </a>
#         </li>
#         <li class="nav-offers flyout-parent">
#          <a class="l1 nav-icn None" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#" tabindex="11">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 50" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             offers icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M35.9 20.6L27 15.5C26.1 15 24.7 15 23.7 15.5L14.9 20.6C13.9 21.1 13.2 22.4 13.2 23.4L13.2 41.4C13.2 42.4 13.9 43.7 14.9 44.2L23.3 49C24.2 49.5 25.6 49.5 26.6 49L35.9 43.6C36.8 43.1 37.6 41.8 37.6 40.8L37.6 23.4C37.6 22.4 36.8 21.1 35.9 20.6L35.9 20.6ZM40 8.2C39.1 7.6 37.6 7.6 36.7 8.2L30.2 11.9C29.3 12.4 29.3 13.2 30.2 13.8L39.1 18.8C40 19.4 40.7 20.6 40.7 21.7L40.7 39C40.7 40.1 41.4 40.5 42.4 40L48.2 36.6C49.1 36.1 49.8 34.9 49.8 33.8L49.8 15.6C49.8 14.6 49.1 13.3 48.2 12.8L40 8.2 40 8.2ZM27 10.1L33.6 6.4C34.5 5.9 34.5 5 33.6 4.5L26.6 0.5C25.6 0 24.2 0 23.3 0.5L16.7 4.2C15.8 4.7 15.8 5.6 16.7 6.1L23.7 10.1C24.7 10.6 26.1 10.6 27 10.1ZM10.1 21.7C10.1 20.6 10.8 19.4 11.7 18.8L20.6 13.8C21.5 13.2 21.5 12.4 20.6 11.9L13.6 7.9C12.7 7.4 11.2 7.4 10.3 7.9L1.6 12.8C0.7 13.3 0 14.6 0 15.6L0 33.8C0 34.9 0.7 36.1 1.6 36.6L8.4 40.5C9.3 41 10.1 40.6 10.1 39.6L10.1 21.7 10.1 21.7Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Offers &amp; Deals
#           </span>
#          </a>
#          <ul class="flyout">
#           <li>
#            <a class="l2 nav-icn" href="https://get.oreilly.com/email-signup.html" tabindex="12" target="_blank">
#             <span>
#              Newsletters
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="nav-highlights">
#          <a class="t-highlights-nav l1 nav-icn None" href="https://learning.oreilly.com/u/0f245ad9-c9d7-4f63-95c5-def519b24116/" tabindex="13">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 35" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             highlights icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M13.325 18.071L8.036 18.071C8.036 11.335 12.36 7.146 22.5 5.594L22.5 0C6.37 1.113 0 10.632 0 22.113 0 29.406 3.477 35 10.403 35 15.545 35 19.578 31.485 19.578 26.184 19.578 21.556 17.211 18.891 13.325 18.071L13.325 18.071ZM40.825 18.071L35.565 18.071C35.565 11.335 39.86 7.146 50 5.594L50 0C33.899 1.113 27.5 10.632 27.5 22.113 27.5 29.406 30.977 35 37.932 35 43.045 35 47.078 31.485 47.078 26.184 47.078 21.556 44.74 18.891 40.825 18.071L40.825 18.071Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Highlights
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="t-settings-nav l1 js-settings nav-icn None" href="https://learning.oreilly.com/u/preferences/" tabindex="14">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 53" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             settings icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M44.6 29.6C44.7 28.6 44.8 27.5 44.8 26.5 44.8 25.5 44.7 24.4 44.6 23.4L49.6 19C50 18.8 50.1 18.3 49.9 17.9 48.9 14.7 47.1 11.7 44.9 9.1 44.6 8.8 44.2 8.7 43.8 8.8L37.4 11.1C35.8 9.8 34 8.7 32.1 8L30.9 1.4C30.8 0.9 30.4 0.6 30 0.5 26.7-0.2 23.3-0.2 20 0.5 19.6 0.6 19.2 0.9 19.1 1.4L17.9 8C16 8.7 14.1 9.8 12.6 11.1L6.2 8.8C5.8 8.7 5.4 8.8 5.1 9.1 2.9 11.7 1.1 14.7 0.1 17.9 -0.1 18.3 0 18.8 0.4 19L5.4 23.4C5.3 24.4 5.2 25.5 5.2 26.5 5.2 27.5 5.3 28.6 5.4 29.6L0.4 34C0 34.2-0.1 34.7 0.1 35.1 1.1 38.3 2.9 41.4 5.1 43.9 5.4 44.2 5.8 44.4 6.2 44.2L12.6 42C14.1 43.2 16 44.3 17.9 45L19.1 51.7C19.2 52.1 19.6 52.5 20 52.5 21.6 52.8 23.3 53 25 53 26.7 53 28.4 52.8 30 52.5 30.4 52.5 30.8 52.1 30.9 51.7L32.1 45C34 44.3 35.8 43.2 37.4 42L43.8 44.2C44.2 44.4 44.6 44.2 44.9 43.9 47.1 41.4 48.9 38.3 49.9 35.1 50.1 34.7 50 34.2 49.6 34L44.6 29.6ZM25 36.4C19.6 36.4 15.2 32 15.2 26.5 15.2 21 19.6 16.6 25 16.6 30.4 16.6 34.8 21 34.8 26.5 34.8 32 30.4 36.4 25 36.4Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Settings
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="l1 no-icon" href="https://www.oreilly.com/online-learning/support/" tabindex="15">
#           Support
#          </a>
#         </li>
#         <li>
#          <a class="l1 no-icon" href="https://learning.oreilly.com/accounts/logout/" tabindex="16">
#           Sign Out
#          </a>
#         </li>
#        </ul>
#        <ul class="profile">
#         <li>
#          <a class="l2 nav-icn None" href="https://learning.oreilly.com/u/preferences/" tabindex="17">
#           <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 53" width="20" xmlns="http://www.w3.org/2000/svg">
#            <desc>
#             settings icon
#            </desc>
#            <g fill-rule="evenodd" stroke="none" stroke-width="1">
#             <path d="M44.6 29.6C44.7 28.6 44.8 27.5 44.8 26.5 44.8 25.5 44.7 24.4 44.6 23.4L49.6 19C50 18.8 50.1 18.3 49.9 17.9 48.9 14.7 47.1 11.7 44.9 9.1 44.6 8.8 44.2 8.7 43.8 8.8L37.4 11.1C35.8 9.8 34 8.7 32.1 8L30.9 1.4C30.8 0.9 30.4 0.6 30 0.5 26.7-0.2 23.3-0.2 20 0.5 19.6 0.6 19.2 0.9 19.1 1.4L17.9 8C16 8.7 14.1 9.8 12.6 11.1L6.2 8.8C5.8 8.7 5.4 8.8 5.1 9.1 2.9 11.7 1.1 14.7 0.1 17.9 -0.1 18.3 0 18.8 0.4 19L5.4 23.4C5.3 24.4 5.2 25.5 5.2 26.5 5.2 27.5 5.3 28.6 5.4 29.6L0.4 34C0 34.2-0.1 34.7 0.1 35.1 1.1 38.3 2.9 41.4 5.1 43.9 5.4 44.2 5.8 44.4 6.2 44.2L12.6 42C14.1 43.2 16 44.3 17.9 45L19.1 51.7C19.2 52.1 19.6 52.5 20 52.5 21.6 52.8 23.3 53 25 53 26.7 53 28.4 52.8 30 52.5 30.4 52.5 30.8 52.1 30.9 51.7L32.1 45C34 44.3 35.8 43.2 37.4 42L43.8 44.2C44.2 44.4 44.6 44.2 44.9 43.9 47.1 41.4 48.9 38.3 49.9 35.1 50.1 34.7 50 34.2 49.6 34L44.6 29.6ZM25 36.4C19.6 36.4 15.2 32 15.2 26.5 15.2 21 19.6 16.6 25 16.6 30.4 16.6 34.8 21 34.8 26.5 34.8 32 30.4 36.4 25 36.4Z">
#             </path>
#            </g>
#           </svg>
#           <span>
#            Settings
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="l2" href="https://www.oreilly.com/online-learning/support/" tabindex="18">
#           Support
#          </a>
#         </li>
#         <li>
#          <a class="l2" href="https://learning.oreilly.com/accounts/logout/" tabindex="19">
#           Sign Out
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#     </ul>
#    </nav>
#   </header>
#   <div class="" id="container">
#    <article data-subscription="active">
#     <header id="lead">
#      <ul>
#       <li class="search t-search-box">
#        <div class="dropdown searchbox wrap-search-form js-is-falcon-search">
#         <div class="drop-content">
#          <form action="https://learning.oreilly.com/search/" id="js-search-form-region">
#           <div class="search-form">
#            <!-- Backbone replaces this div -->
#            <select class="search-params js-search-filter" name="field" tabindex="20" title="Search in">
#             <option class="search" selected="" value="">
#              Everything
#             </option>
#             <option value="title">
#              Title
#             </option>
#             <option value="authors">
#              Author
#             </option>
#             <option value="publishers">
#              Publisher
#             </option>
#            </select>
#            <span class="js-option hidden">
#            </span>
#            <input autocomplete="off" class="search-query" name="query" tabindex="21" type="search" value=""/>
#            <button class="search-button" tabindex="22">
#             <svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 50" width="20" xmlns="http://www.w3.org/2000/svg">
#              <desc>
#               search icon
#              </desc>
#              <g fill-rule="evenodd" stroke="none" stroke-width="1">
#               <path d="M31.3 0C20.9 0 12.5 8.4 12.5 18.8 12.5 22.5 13.6 25.9 15.4 28.8L1.2 42.9C-0.4 44.5-0.4 47.2 1.2 48.8 2 49.6 3.1 50 4.2 50 5.2 50 6.3 49.6 7.1 48.8L21.2 34.6C24.1 36.5 27.5 37.5 31.3 37.5 41.6 37.5 50 29.1 50 18.8 50 8.4 41.6 0 31.3 0ZM31.3 31.3C24.4 31.3 18.8 25.6 18.8 18.8 18.8 11.9 24.4 6.3 31.3 6.3 38.1 6.3 43.8 11.9 43.8 18.8 43.8 25.6 38.1 31.3 31.3 31.3Z">
#               </path>
#              </g>
#             </svg>
#             <span>
#              Search
#             </span>
#            </button>
#            <div id="js-suggest-results-region">
#             <!-- auto suggest results rendered here -->
#            </div>
#           </div>
#          </form>
#         </div>
#        </div>
#       </li>
#      </ul>
#     </header>
#     <!--[if lt IE 9]>
#
# <![endif]-->
#     <script defer="" src="./Think Stats, 2nd Edition_files/djangoMessagesPage.6d18de30c1a1.js.download">
#     </script>
#     <section class="pod detail-book js-title-detail-page">
#      <div class="title-info">
#       <div class="cover t-cover">
#        <a class="t-cover-position-link" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch05.html" tabindex="23">
#         <span>
#          <img alt="Cover image for Think Stats, 2nd Edition" height="184" src="./Think Stats, 2nd Edition_files/saved_resource(1)" width="140"/>
#         </span>
#        </a>
#       </div>
#       <div class="metadata">
#        <h1 class="title t-title">
#         Think Stats, 2nd Edition
#        </h1>
#        <div class="review-report" data-format="book" data-identifier="9781491907344" data-title="Think Stats, 2nd Edition">
#         <span class="review-stars rateit rating-wrapper tabbable-item" data-rateit-starheight="18" data-rateit-starwidth="18" tabindex="24">
#          <button aria-controls="rateit-range-2" aria-label="reset rating" class="rateit-reset" data-role="none" id="rateit-reset-2" style="display: none;" tabindex="25" type="button">
#          </button>
#          <span aria-label="rating" aria-owns="rateit-reset-2" aria-readonly="false" aria-valuemax="5" aria-valuemin="0" aria-valuenow="4.857" class="rateit-range" id="rateit-range-2" role="slider" style="width: 90px; height: 18px;" tabindex="26">
#           <span class="rateit-selected" style="height: 18px; width: 87.426px;">
#           </span>
#           <span class="rateit-hover" style="height:18px">
#           </span>
#          </span>
#         </span>
#         <span class="review-total">
#          <button aria-label="Open Reviews" class="open-reviews plain-txt-btn" tabindex="27">
#           7
#
#        Reviews
#          </button>
#         </span>
#        </div>
#        <div class="author t-author">
#         by
#         <a class="js-search-again-link" href="https://learning.oreilly.com/search/?query=author%3A%22Allen%20B.%20Downey%22&amp;sort=relevance&amp;highlight=true" tabindex="28">
#          Allen B. Downey
#         </a>
#        </div>
#        <div class="publisher t-publisher">
#         Publisher:
#         <a class="js-search-again-link" href="https://learning.oreilly.com/library/publisher/oreilly-media-inc/" tabindex="29">
#          O'Reilly Media, Inc.
#         </a>
#        </div>
#        <div class="issued t-issued">
#         Release Date: October 2014
#        </div>
#        <div class="isbn t-isbn">
#         ISBN: 9781491907337
#        </div>
#        <div class="book-topics">
#         Topic:
#         <ul class="topic-display">
#          <li>
#           <a class="topic t-t-link" data-topic-slug="statistics" href="https://learning.oreilly.com/topics/statistics" tabindex="30">
#            Statistics
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="js-content-uri" data-content-uri="/api/v1/book/9781491907344/">
#         <div class="js-collections-dropdown collections-dropdown menu-bit-cards">
#          <div class="menu-dropdown-wrapper js-menu-dropdown-wrapper align-right" data-reactroot="">
#           <img alt="loading spinner" class="hidden" src="./Think Stats, 2nd Edition_files/ajax-transp.gif"/>
#           <div class="menu-control">
#            <div class="control ">
#             <div class="js-playlists-menu">
#              <button class="js-playlist-icon">
#               <svg class="icon-added-to-playlist-sml" version="1.1" viewbox="0 0 16 14" xmlns="http://www.w3.org/2000/svg">
#                <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                 <g fill="#000000" fill-rule="nonzero">
#                  <g>
#                   <path d="M3.21246459,13.3814663 L7,9.69833039 L5.9490085,8.66666667 L2.50849858,12.0123425 L1.0509915,10.5950101 L0,11.6170321 L1.80453258,13.3814663 C1.99070343,13.5639962 2.24412709,13.6666667 2.50849858,13.6666667 C2.77287008,13.6666667 3.02629374,13.5639962 3.21246459,13.3814663 L3.21246459,13.3814663 Z">
#                   </path>
#                   <g>
#                    <rect height="1.86666667" width="11.7851662" x="4.21483376" y="0">
#                    </rect>
#                    <ellipse cx="1.2685422" cy="4.66666667" rx="1" ry="1">
#                    </ellipse>
#                    <ellipse cx="1.2685422" cy="0.933333333" rx="1" ry="1">
#                    </ellipse>
#                    <rect height="1.86666667" width="11.7851662" x="4.21483376" y="3.73333333">
#                    </rect>
#                    <rect height="1.86666667" width="7.85677749" x="8.14322251" y="7.46666667">
#                    </rect>
#                    <rect height="1.86666667" width="7.85677749" x="8.14322251" y="11.2">
#                    </rect>
#                   </g>
#                  </g>
#                 </g>
#                </g>
#               </svg>
#               <div class="js-playlist-addto-label">
#                Add To
#               </div>
#              </button>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="action">
#        <span class="js-title-detail start-reading">
#         <a class="button position-link t-position-link js-position-book" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch05.html" tabindex="31">
#          Continue Reading
#         </a>
#        </span>
#        <div>
#         <a href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#toc" tabindex="32">
#          View table of contents
#         </a>
#        </div>
#        <div>
#         <a class="purchase-link" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#publisher_resources" tabindex="33">
#          Publisher Resources
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="description t-description">
#       <h2>
#        Book Description
#       </h2>
#       <span>
#        <span>
#         <span>
#          <span>
#           <span>
#            <p>
#             If you know how to program, you have the skills to turn data into knowledge, using tools of probability and statistics. This concise introduction shows you how to perform statistical analysis computationally, rather than mathematically, with programs written in Python. You’ll learn the entire process of exploratory data analysis—from collecting data and generating statistics to identifying patterns and testing hypotheses.
#            </p>
#           </span>
#          </span>
#         </span>
#        </span>
#       </span>
#      </div>
#      <div class="description t-description">
#       <h2 id="publisher_resources">
#        Publisher Resources
#       </h2>
#       <ul class="resources">
#        <li>
#         Errata:
#         <a href="http://oreilly.com/catalog/0636920034094/errata" tabindex="34" target="=_blank">
#          http://oreilly.com/catalog/0636920034094/errata
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="publisher-extra t-publisher-extra">
#       <h2>
#        About the Publisher
#       </h2>
#       <a class="t-publisher-logo-link" href="https://learning.oreilly.com/library/publisher/oreilly-media-inc/" tabindex="35">
#        <img class="publisher-logo t-publisher-logo" src="./Think Stats, 2nd Edition_files/ORM_logo_box_rgb.png"/>
#       </a>
#       <div class="publisher-description t-publisher-description">
#        <p class="fsl">
#         O’Reilly Media spreads the knowledge of innovators through online and in-person training, books, videos, research, and conferences. Since 1978, O’Reilly has been a chronicler and catalyst of leading-edge development, homing in on the ...
#        </p>
#       </div>
#       <a class="publisher-link t-publisher-link" href="https://learning.oreilly.com/library/publisher/oreilly-media-inc/" tabindex="36">
#        More about O'Reilly Media, Inc.
#       </a>
#      </div>
#      <h2 id="toc">
#       Table of Contents
#      </h2>
#      <ol class="detail-toc">
#       <li class="toc-level-1 t-toc-level-1 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#        <div align="left" class="js-collections-dropdown collections-dropdown menu-bit-cards t-collections-dropdown condensed">
#         <div class="menu-dropdown-wrapper js-menu-dropdown-wrapper align-left" data-reactroot="">
#          <img alt="loading spinner" class="hidden" src="./Think Stats, 2nd Edition_files/ajax-transp.gif"/>
#          <div class="menu-control">
#           <div class="control ">
#            <div class="js-playlists-menu">
#             <button class="js-playlist-icon">
#              <svg class="icon-add-to-playlist-sml" version="1.1" viewbox="0 0 16 14" xmlns="http://www.w3.org/2000/svg">
#               <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                <g fill="#000000" fill-rule="nonzero">
#                 <g transform="translate(-1.000000, 0.000000)">
#                  <rect height="2" width="12" x="5" y="0">
#                  </rect>
#                  <title>
#                   Playlists
#                  </title>
#                  <path d="M4.5,14 C6.43299662,14 8,12.4329966 8,10.5 C8,8.56700338 6.43299662,7 4.5,7 C2.56700338,7 1,8.56700338 1,10.5 C1,12.4329966 2.56700338,14 4.5,14 Z M2.5,10 L4,10 L4,8.5 L5,8.5 L5,10 L6.5,10 L6.5,11 L5,11 L5,12.5 L4,12.5 L4,11 L2.5,11 L2.5,10 Z">
#                  </path>
#                  <circle cx="2" cy="5" r="1">
#                  </circle>
#                  <circle cx="1.94117647" cy="1" r="1">
#                  </circle>
#                  <rect height="2" width="12" x="5" y="4">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="8">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="12">
#                  </rect>
#                 </g>
#                </g>
#               </g>
#              </svg>
#              <div class="js-playlist-addto-label">
#               Add To
#              </div>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html" tabindex="37">
#         Preface
#        </a>
#        <ol>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html#a0000000120" tabindex="38">
#           How I Wrote This Book
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html#code" tabindex="39">
#           Using the Code
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html#a0000000194" tabindex="40">
#           Contributor List
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html#id288169" tabindex="41">
#           Safari® Books Online
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/pr01.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/pr01.html#id288262" tabindex="42">
#           How to Contact Us
#          </a>
# ...
#                  </circle>
#                  <circle cx="1.94117647" cy="1" r="1">
#                  </circle>
#                  <rect height="2" width="12" x="5" y="4">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="8">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="12">
#                  </rect>
#                 </g>
#                </g>
#               </g>
#              </svg>
#              <div class="js-playlist-addto-label">
#               Add To
#              </div>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html" tabindex="186">
#         14. Analytic Methods
#        </a>
#        <ol>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#why_normal" tabindex="187">
#           Normal Distributions
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007474" tabindex="188">
#           Sampling Distributions
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007569" tabindex="189">
#           Representing Normal Distributions
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#CLT" tabindex="190">
#           Central Limit Theorem
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007639" tabindex="191">
#           Testing the CLT
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#usingCLT" tabindex="192">
#           Applying the CLT
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007816" tabindex="193">
#           Correlation Test
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007888" tabindex="194">
#           Chi-Squared Test
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007936" tabindex="195">
#           Discussion
#          </a>
#         </li>
#         <li class="toc-level-2 t-toc-level-2 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ch14.html">
#          <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ch14.html#a0000007965" tabindex="196">
#           Exercises
#          </a>
#         </li>
#        </ol>
#       </li>
#       <li class="toc-level-1 t-toc-level-1 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/ix01.html">
#        <div align="left" class="js-collections-dropdown collections-dropdown menu-bit-cards t-collections-dropdown condensed">
#         <div class="menu-dropdown-wrapper js-menu-dropdown-wrapper align-left" data-reactroot="">
#          <img alt="loading spinner" class="hidden" src="./Think Stats, 2nd Edition_files/ajax-transp.gif"/>
#          <div class="menu-control">
#           <div class="control ">
#            <div class="js-playlists-menu">
#             <button class="js-playlist-icon">
#              <svg class="icon-add-to-playlist-sml" version="1.1" viewbox="0 0 16 14" xmlns="http://www.w3.org/2000/svg">
#               <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                <g fill="#000000" fill-rule="nonzero">
#                 <g transform="translate(-1.000000, 0.000000)">
#                  <rect height="2" width="12" x="5" y="0">
#                  </rect>
#                  <title>
#                   Playlists
#                  </title>
#                  <path d="M4.5,14 C6.43299662,14 8,12.4329966 8,10.5 C8,8.56700338 6.43299662,7 4.5,7 C2.56700338,7 1,8.56700338 1,10.5 C1,12.4329966 2.56700338,14 4.5,14 Z M2.5,10 L4,10 L4,8.5 L5,8.5 L5,10 L6.5,10 L6.5,11 L5,11 L5,12.5 L4,12.5 L4,11 L2.5,11 L2.5,10 Z">
#                  </path>
#                  <circle cx="2" cy="5" r="1">
#                  </circle>
#                  <circle cx="1.94117647" cy="1" r="1">
#                  </circle>
#                  <rect height="2" width="12" x="5" y="4">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="8">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="12">
#                  </rect>
#                 </g>
#                </g>
#               </g>
#              </svg>
#              <div class="js-playlist-addto-label">
#               Add To
#              </div>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/ix01.html" tabindex="197">
#         Index
#        </a>
#       </li>
#       <li class="toc-level-1 t-toc-level-1 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/co01.html">
#        <div align="left" class="js-collections-dropdown collections-dropdown menu-bit-cards t-collections-dropdown condensed">
#         <div class="menu-dropdown-wrapper js-menu-dropdown-wrapper align-left" data-reactroot="">
#          <img alt="loading spinner" class="hidden" src="./Think Stats, 2nd Edition_files/ajax-transp.gif"/>
#          <div class="menu-control">
#           <div class="control ">
#            <div class="js-playlists-menu">
#             <button class="js-playlist-icon">
#              <svg class="icon-add-to-playlist-sml" version="1.1" viewbox="0 0 16 14" xmlns="http://www.w3.org/2000/svg">
#               <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                <g fill="#000000" fill-rule="nonzero">
#                 <g transform="translate(-1.000000, 0.000000)">
#                  <rect height="2" width="12" x="5" y="0">
#                  </rect>
#                  <title>
#                   Playlists
#                  </title>
#                  <path d="M4.5,14 C6.43299662,14 8,12.4329966 8,10.5 C8,8.56700338 6.43299662,7 4.5,7 C2.56700338,7 1,8.56700338 1,10.5 C1,12.4329966 2.56700338,14 4.5,14 Z M2.5,10 L4,10 L4,8.5 L5,8.5 L5,10 L6.5,10 L6.5,11 L5,11 L5,12.5 L4,12.5 L4,11 L2.5,11 L2.5,10 Z">
#                  </path>
#                  <circle cx="2" cy="5" r="1">
#                  </circle>
#                  <circle cx="1.94117647" cy="1" r="1">
#                  </circle>
#                  <rect height="2" width="12" x="5" y="4">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="8">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="12">
#                  </rect>
#                 </g>
#                </g>
#               </g>
#              </svg>
#              <div class="js-playlist-addto-label">
#               Add To
#              </div>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/co01.html" tabindex="198">
#         Colophon
#        </a>
#       </li>
#       <li class="toc-level-1 t-toc-level-1 js-content-uri" data-content-uri="/api/v1/book/9781491907344/chapter/copyright.html">
#        <div align="left" class="js-collections-dropdown collections-dropdown menu-bit-cards t-collections-dropdown condensed">
#         <div class="menu-dropdown-wrapper js-menu-dropdown-wrapper align-left" data-reactroot="">
#          <img alt="loading spinner" class="hidden" src="./Think Stats, 2nd Edition_files/ajax-transp.gif"/>
#          <div class="menu-control">
#           <div class="control ">
#            <div class="js-playlists-menu">
#             <button class="js-playlist-icon">
#              <svg class="icon-add-to-playlist-sml" version="1.1" viewbox="0 0 16 14" xmlns="http://www.w3.org/2000/svg">
#               <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#                <g fill="#000000" fill-rule="nonzero">
#                 <g transform="translate(-1.000000, 0.000000)">
#                  <rect height="2" width="12" x="5" y="0">
#                  </rect>
#                  <title>
#                   Playlists
#                  </title>
#                  <path d="M4.5,14 C6.43299662,14 8,12.4329966 8,10.5 C8,8.56700338 6.43299662,7 4.5,7 C2.56700338,7 1,8.56700338 1,10.5 C1,12.4329966 2.56700338,14 4.5,14 Z M2.5,10 L4,10 L4,8.5 L5,8.5 L5,10 L6.5,10 L6.5,11 L5,11 L5,12.5 L4,12.5 L4,11 L2.5,11 L2.5,10 Z">
#                  </path>
#                  <circle cx="2" cy="5" r="1">
#                  </circle>
#                  <circle cx="1.94117647" cy="1" r="1">
#                  </circle>
#                  <rect height="2" width="12" x="5" y="4">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="8">
#                  </rect>
#                  <rect height="2" width="8" x="9" y="12">
#                  </rect>
#                 </g>
#                </g>
#               </g>
#              </svg>
#              <div class="js-playlist-addto-label">
#               Add To
#              </div>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="t-chapter" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/copyright.html" tabindex="199">
#         Copyright
#        </a>
#       </li>
#      </ol>
#     </section>
#     <footer class="pagefoot t-pagefoot">
#      <a class="icon-up" href="https://learning.oreilly.com/library/view/think-stats-2nd/9781491907344/#" tabindex="200">
#       <div class="visuallyhidden">
#        Back to top
#       </div>
#      </a>
#      <ul class="js-footer-nav">
#       <li>
#        <a class="t-recommendations-footer" href="https://learning.oreilly.com/r/" tabindex="201">
#         Recommended
#        </a>
#       </li>
#       <li>
#        <a class="t-queue-footer" href="https://learning.oreilly.com/playlists/" tabindex="202">
#         Playlists
#        </a>
#       </li>
#       <li>
#        <a class="t-recent-footer" href="https://learning.oreilly.com/history/" tabindex="203">
#         History
#        </a>
#       </li>
#       <li>
#        <a class="t-topics-footer" href="https://learning.oreilly.com/topics?q=*&amp;limit=21" tabindex="204">
#         Topics
#        </a>
#       </li>
#       <li>
#        <a class="t-tutorials-footer" href="https://learning.oreilly.com/tutorials/" tabindex="205">
#         Tutorials
#        </a>
#       </li>
#       <li>
#        <a class="t-settings-footer js-settings" href="https://learning.oreilly.com/u/preferences/" tabindex="206">
#         Settings
#        </a>
#       </li>
#       <li class="full-support">
#        <a href="https://www.oreilly.com/online-learning/support/" tabindex="207">
#         Support
#        </a>
#       </li>
#       <li>
#        <a href="https://learning.oreilly.com/online-learning/apps.html" tabindex="208">
#         Get the App
#        </a>
#       </li>
#       <li>
#        <a href="https://learning.oreilly.com/accounts/logout/" tabindex="209">
#         Sign Out
#        </a>
#       </li>
#      </ul>
#      <span class="copyright">
#       © 2019
#       <a href="https://learning.oreilly.com/" tabindex="210" target="_blank">
#        Safari
#       </a>
#       .
#      </span>
#      <a href="https://learning.oreilly.com/terms/" tabindex="211">
#       Terms of Service
#      </a>
#      /
#      <a href="https://learning.oreilly.com/privacy.html" tabindex="212">
#       Privacy Policy
#      </a>
#     </footer>
#     <script type="text/javascript">
#      window.NREUM||(NREUM={});NREUM.info={"agent":"","applicationTime":138,"errorBeacon":"bam.nr-data.net","applicationID":"3275661,67267027,67267028","transactionName":"YgdaZ0NSW0cEB0RdWltNfkZfUEFdCgofXFBHDVYdR1pQQxZeRF1BWQdnV1RHVF0J","licenseKey":"510f1a6865","queueTime":2,"beacon":"bam.nr-data.net"}
#     </script>
#    </article>
#   </div>
#   <script id="" type="text/javascript">
#    (function(){function b(){!1===c&&(c=!0,Munchkin.init("107-FMS-070"))}var c=!1,a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="//munchkin.marketo.net/munchkin.js";a.onreadystatechange=function(){"complete"!=this.readyState&&"loaded"!=this.readyState||b()};a.onload=b;document.getElementsByTagName("head")[0].appendChild(a)})();
#   </script>
#   <script id="" type="text/javascript">
#    (function(){window.medalliaUserIdentifier=document.documentElement.dataset.userUuid;window.medalliaUserName=document.documentElement.dataset.username})();
#   </script>
#   <script id="" src="./Think Stats, 2nd Edition_files/embed.js.download" type="text/javascript">
#   </script>
#   <script id="" src="./Think Stats, 2nd Edition_files/digitalpi-utm-tracker-oreilly.com.js.download" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1732687426968531");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1732687426968531&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <div id="batBeacon0.8300967547994849" style="width:0px; height:0px; display:none; visibility:hidden;">
#    <img alt="" height="0" id="batBeacon0.12256369065535466" src="./Think Stats, 2nd Edition_files/0" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#   </div>
#   <iframe src="./Think Stats, 2nd Edition_files/pixel.html" style="display: none;">
#   </iframe>
#   <script async="" charset="UTF-8" src="./Think Stats, 2nd Edition_files/generic1546639477551.js.download" type="text/javascript">
#   </script>
#   <span>
#    <div id="KampyleAnimationContainer" style="z-index: 2147483000; border: 0px; position: fixed; display: block; width: 0px; height: 0px;">
#    </div>
#   </span>
#   <div id="content-script" style="display: none;">
#    <div id="content-main">
#     <iframe id="portal-section" src="./Think Stats, 2nd Edition_files/saved_resource.html" style="width: 0px; height: 0px;">
#     </iframe>
#     <div class="page" id="page-login">
#      <div class="E2Module" template="Login/login">
#      </div>
#     </div>
#     <div class="page" id="page-loading">
#      <div class="E2Module" template="Loading/loading">
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## Find specific sections based on both tag and class

# %%
for i in safari_soup.find_all('a', class_="t-chapter"):
    print(i.get_text())
# Out:
# Preface
# How I Wrote This Book
# Using the Code
# Contributor List
# Safari® Books Online
# How to Contact Us
# 1. Exploratory Data Analysis
# A Statistical Approach
# The National Survey of Family Growth
# Importing the Data
# DataFrames
# Variables
# Transformation
# Validation
# Interpretation
# Exercises
# Glossary
# 2. Distributions
# Representing Histograms
# Plotting Histograms
# NSFG Variables
# Outliers
# First Babies
# Summarizing Distributions
# Variance
# Effect Size
# Reporting Results
# Exercises
# Glossary
# 3. Probability Mass Functions
# Pmfs
# Plotting PMFs
# Other Visualizations
# The Class Size Paradox
# DataFrame Indexing
# Exercises
# Glossary
# 4. Cumulative Distribution Functions
# The Limits of PMFs
# Percentiles
# CDFs
# Representing CDFs
# Comparing CDFs
# Percentile-Based Statistics
# Random Numbers
# Comparing Percentile Ranks
# Exercises
# Glossary
# 5. Modeling Distributions
# The Exponential Distribution
# The Normal Distribution
# Normal Probability Plot
# The lognormal Distribution
# The Pareto Distribution
# Generating Random Numbers
# Why Model?
# Exercises
# Glossary
# 6. Probability Density Functions
# PDFs
# Kernel Density Estimation
# The Distribution Framework
# Hist Implementation
# Pmf Implementation
# Cdf Implementation
# Moments
# Skewness
# Exercises
# Glossary
# 7. Relationships Between Variables
# Scatter Plots
# Characterizing Relationships
# Correlation
# Covariance
# Pearson’s Correlation
# Nonlinear Relationships
# Spearman’s Rank Correlation
# Correlation and Causation
# Exercises
# Glossary
# 8. Estimation
# The Estimation Game
# Guess the Variance
# Sampling Distributions
# Sampling Bias
# Exponential Distributions
# Exercises
# Glossary
# 9. Hypothesis Testing
# Classical Hypothesis Testing
# HypothesisTest
# Testing a Difference in Means
# Other Test Statistics
# Testing a Correlation
# Testing Proportions
# Chi-Squared Tests
# First Babies Again
# Errors
# Power
# Replication
# Exercises
# Glossary
# 10. Linear Least Squares
# Least Squares Fit
# Implementation
# Residuals
# Estimation
# Goodness of Fit
# Testing a Linear Model
# Weighted Resampling
# Exercises
# Glossary
# 11. Regression
# StatsModels
# Multiple Regression
# Nonlinear Relationships
# Data Mining
# Prediction
# Logistic Regression
# Estimating Parameters
# Implementation
# Accuracy
# Exercises
# Glossary
# 12. Time Series Analysis
# Importing and Cleaning
# Plotting
# Linear Regression
# Moving Averages
# Missing Values
# Serial Correlation
# Autocorrelation
# Prediction
# Further Reading
# Exercises
# Glossary
# 13. Survival Analysis
# Survival Curves
# Hazard Function
# Estimating Survival Curves
# Kaplan-Meier Estimation
# The Marriage Curve
# Estimating the Survival Function
# Confidence Intervals
# Cohort Effects
# Extrapolation
# Expected Remaining Lifetime
# Exercises
# Glossary
# 14. Analytic Methods
# Normal Distributions
# Sampling Distributions
# Representing Normal Distributions
# Central Limit Theorem
# Testing the CLT
# Applying the CLT
# Correlation Test
# Chi-Squared Test
# Discussion
# Exercises
# Index
# Colophon
# Copyright

# %% [markdown]
# ## Get only the parts I want

# %%
# create a list of numbers converted to strings and converted to a tuple
chap_nums = tuple([str(i) + '.' for i in range(1, 20)])

for i in safari_soup.find_all('a', class_="t-chapter"):
    
    # use startswith to check if it begins with a number
    if i.get_text().startswith(chap_nums):
        print(i.get_text())
# Out:
# 1. Exploratory Data Analysis
# 2. Distributions
# 3. Probability Mass Functions
# 4. Cumulative Distribution Functions
# 5. Modeling Distributions
# 6. Probability Density Functions
# 7. Relationships Between Variables
# 8. Estimation
# 9. Hypothesis Testing
# 10. Linear Least Squares
# 11. Regression
# 12. Time Series Analysis
# 13. Survival Analysis
# 14. Analytic Methods

# %% [markdown]
# # Automate with Requests

# %% [markdown]
# ### Here we are doing the same thing as above, but using requests to grab the html

# %%
import requests

# r = requests.get('https://learning.oreilly.com/library/view/python-machine-learning/9781786464477/')
r = requests.get('https://learning.oreilly.com/library/view/r-for-data/9781491910382/')
# r = requests.get('https://www.safaribooksonline.com/library/view/python-data-science/9781491912126/')

# %%
soup_requests = BeautifulSoup(r.text, 'html.parser')

for i in soup_requests.find_all('a', class_="t-chapter"):
    if i.get_text().startswith(chap_nums):
        print(i.get_text())
# Out:
# 1. Data Visualization with ggplot2
# 2. Workflow: Basics
# 3. Data Transformation with dplyr
# 4. Workflow: Scripts
# 5. Exploratory Data Analysis
# 6. Workflow: Projects
# 7. Tibbles with tibble
# 8. Data Import with readr
# 9. Tidy Data with tidyr
# 10. Relational Data with dplyr
# 11. Strings with stringr
# 12. Factors with forcats
# 13. Dates and Times with lubridate
# 14. Pipes with magrittr
# 15. Functions
# 16. Vectors
# 17. Iteration with purrr
# 18. Model Basics with modelr
# 19. Model Building

# %% [markdown]
# # Logging into a site
# - [Overcast podcast player website](https://overcast.fm)
# - [Full Code example](https://www.pythonanywhere.com/user/JBalloonist/files/home/JBalloonist/RTM/getovercast.py?edit)

# %%
# import username and password
from const import payload

LOGIN_URL = 'https://overcast.fm/login'
PODCASTS = 'https://overcast.fm/podcasts'
OVERCAST = 'https://overcast.fm'

# Use 'with' to ensure the session context is closed after use.
with requests.Session() as s:
    p = s.post(LOGIN_URL, data=payload)
    r = s.get(PODCASTS)
    soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="controller_podcasts" lang="en">
#  <head>
#   <title>
#    Overcast
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link color="#fc7e0f" href="/img/logo-black.svg" rel="mask-icon"/>
#   <link href="/favicon.ico" rel="icon"/>
#   <link href="/pure-min-0.5.0.css" rel="stylesheet" type="text/css"/>
#   <link href="/grids-responsive-min-0.5.0.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/48/main.css" rel="stylesheet" type="text/css"/>
#   <script src="/assets/48/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="/assets/48/main.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="nav">
#    <a class="left navlink" href="/podcasts">
#     <img alt="Overcast" class="narrow" id="tinyhomeimg" src="/img/logo.svg"/>
#     <span class="notnarrow">
#      Overcast
#     </span>
#    </a>
#    <a class="left navlink" href="/uploads">
#     Uploads
#    </a>
#    <a class="left navlink" href="/account">
#     Account
#    </a>
#    <div class="right pure-form search_container">
#     <input autocomplete="off" class="podcastsearchbox pure-input-rounded" data-autocomplete-target="" id="ocpodcastsearch" name="q" placeholder="Search Podcasts" type="text"/>
#     <div id="autocomplete_container">
#      <div id="autocomplete_results">
#      </div>
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#   <div class="container pure-g">
#    <div class="content pure-u-1">
#     <div class="pure-g">
#      <div class="pure-u-1-5">
#      </div>
#      <div class="pure-u-1 pure-u-sm-3-5">
#       <h2 class="ocseparatorbar">
#        Recent Episodes
#       </h2>
#       <a class="episodecell" href="/+diwIS06l9Hs">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           7_flat_is_better_than_nested
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+ZGhMAe-suqQ">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           6_send_an_exit_code
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+dGxQQ9t0Fr8">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           5_string_formatting
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cuiAwHlqUPI">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           4_choose_random_item
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+eMqfn6vyJiE">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           3_multiple_tests_one_variable
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+ZdmTaV7fNjQ">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           2_test_for_none
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+f0N8x6vCBg0">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           1_truthiness
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+ZOxFAipf6ik">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           5_pep8_naming
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+fBnSqvFd3R4">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           4_pep8_docs
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+bHmXyrIemtk">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           3_pep8_layout
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+baY6NgZ2hDA">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           2_pep8
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+eAdOzkZyqZY">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           1_foundations_pep8
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+eg2Zz6W2npk">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP034
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+frMHNFIVfAs">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP033
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cwnvMY1PQBA">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP032
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+dW6yRgSUUpQ">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP031
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+bwrN7NehlZ8">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP030
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cieuwDe-MEc">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP029
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+ezadpd68fFo">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP028
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cbRSh_cYOT8">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP027
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+biiOJ-qKiuM">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP026
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+a-sqzl_4FLc">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP023
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cX4UiV-YZGk">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP024
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+YGoJVlEB73I">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP021
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+eh54U3Nuh0I">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP020
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cvn7YQEaboA">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP019
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+fhfsue84qEM">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP018
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cW88CGgVmDo">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP017
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+aZMnxOA0GjE">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP016
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+e0YMHVIxKz8">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP015
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+dDH2ZYh_5_0">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP014
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+aJE30Jg0rXk">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP013
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+Z8QfwQJ21w0">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP012
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+YntnGsYCGMo">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP025
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+cOK_7_W8yP8">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP011
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+Yi4KlWWmSV0">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP010
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+YoAtgwUOsDk">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP008
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+Zr4SHpPAY2c">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP007
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+eZYN9FFvET0">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP006
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2017 • at 42 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+f7Quaau-TcU">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           UCAP022
#          </div>
#          <div class="caption2 singleline">
#           Jun 9, 2017
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+YSpqkCIwc8g">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           From $0 to $2.8M and early retirement in New York City with JP Livingston
#          </div>
#          <div class="caption2 singleline">
#           Apr 25, 2017 • at 0 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+ZTSV64NH6jc">
#        <img class="art" src="https://overcast.fm/img/default-artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           Uploads
#          </div>
#          <div class="title singleline">
#           A New Take on What's Important in Life with Mrs. Frugalwoods
#          </div>
#          <div class="caption2 singleline">
#           Apr 25, 2017 • at 0 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzHqAXU">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           504 - The Lego Movie 2: The Second Part and Russian Doll
#          </div>
#          <div class="caption2 singleline">
#           Feb 11 • 62 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwVu5w0">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           503 - Velvet Buzzsaw and Burning (GUESTS: April Wolfe and Dan Gvozden)
#          </div>
#          <div class="caption2 singleline">
#           Feb 5 • 102 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCye6jgg">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           502 - The Kid Who Would Be King and Serenity
#          </div>
#          <div class="caption2 singleline">
#           Jan 29 • 116 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwKgKqE">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           502 - The Kid Who Would Be King and Serenity
#          </div>
#          <div class="caption2 singleline">
#           Jan 29 • 116 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCyKocW8">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           501 - Glass
#          </div>
#          <div class="caption2 singleline">
#           Jan 22 • 125 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCyhuMzI">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           500 - The /Filmcast’s 500th Episode Extravaganza
#          </div>
#          <div class="caption2 singleline">
#           Jan 15 • 170 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzT82CE">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           Bonus Ep. - Black Mirror: Bandersnatch and Bird Box
#          </div>
#          <div class="caption2 singleline">
#           Jan 7 • 39 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCxRBRJE">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           499 - The Top 10 Films of 2018
#          </div>
#          <div class="caption2 singleline">
#           Jan 3 • 145 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwabBhY">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           498 - Aquaman
#          </div>
#          <div class="caption2 singleline">
#           Dec 23, 2018 • 74 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwAGTcY">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           496 - Roma and The Favourite (GUEST: Britt Hayes)
#          </div>
#          <div class="caption2 singleline">
#           Dec 12, 2018 • 104 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCyAAB7I">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           495 - Creed II (GUEST: Joseph Kahn, director of Bodied)
#          </div>
#          <div class="caption2 singleline">
#           Dec 5, 2018 • 86 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwlZsrw">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           Bonus Ep. - The Ballad of Buster Scruggs
#          </div>
#          <div class="caption2 singleline">
#           Nov 27, 2018 • 43 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCyZCcPQ">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           494 - Widows (GUEST: Aisha Harris from The New York Times)
#          </div>
#          <div class="caption2 singleline">
#           Nov 20, 2018 • 80 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCziGe4g">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           493 - Overlord
#          </div>
#          <div class="caption2 singleline">
#           Nov 13, 2018 • 78 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwGVoG0">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           492 - Suspiria (GUEST: Britt Hayes and Lindsey Romain)
#          </div>
#          <div class="caption2 singleline">
#           Nov 6, 2018 • 116 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCxSL5jc">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           491 - Private Life and The Old Man &amp; the Gun
#          </div>
#          <div class="caption2 singleline">
#           Oct 30, 2018 • 90 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwJd_KM">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           490 - Halloween
#          </div>
#          <div class="caption2 singleline">
#           Oct 23, 2018 • 85 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwMNCqI">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           489 - First Man and Bad Times at the El Royale (GUEST: Lindsey Romain)
#          </div>
#          <div class="caption2 singleline">
#           Oct 16, 2018 • 78 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCz4DX38">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           488 - Venom and A Star Is Born (GUEST: Angie Han from Mashable)
#          </div>
#          <div class="caption2 singleline">
#           Oct 9, 2018 • 87 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCxmkAz0">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           487 - Minding the Gap
#          </div>
#          <div class="caption2 singleline">
#           Oct 2, 2018 • 91 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzDCnqE">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           486 - Mandy
#          </div>
#          <div class="caption2 singleline">
#           Sep 25, 2018 • 81 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCw7mwWY">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           485 - The Predator and Ozark: Season 2
#          </div>
#          <div class="caption2 singleline">
#           Sep 18, 2018 • 107 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzFvkh0">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           The 2018 Summer Movie Wager Results
#          </div>
#          <div class="caption2 singleline">
#           Sep 11, 2018 • 96 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCy2KgBY">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           483 - Searching
#          </div>
#          <div class="caption2 singleline">
#           Sep 5, 2018 • 87 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCxP4DYk">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           482 - The Happytime Murders
#          </div>
#          <div class="caption2 singleline">
#           Aug 28, 2018 • 78 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCwhNYvI">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           481 - Crazy Rich Asians and HBO’s Succession
#          </div>
#          <div class="caption2 singleline">
#           Aug 21, 2018 • 101 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCy8Zyqc">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           480 - The Meg and BlackkKlansman
#          </div>
#          <div class="caption2 singleline">
#           Aug 14, 2018 • 79 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzRyXdM">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           479 - Blindspotting and Christopher Robin
#          </div>
#          <div class="caption2 singleline">
#           Aug 7, 2018 • 107 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCykS45c">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           478 - Mission: Impossible - Fallout (GUEST: Patrick Willems)
#          </div>
#          <div class="caption2 singleline">
#           Jul 31, 2018 • 120 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCzgRNWc">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           477 - Sorry to Bother You
#          </div>
#          <div class="caption2 singleline">
#           Jul 25, 2018 • 97 min
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="episodecell" href="/+PsCztzrzw">
#        <img class="art" src="https://overcast.fm/art?s=3d1c9e5ab7dac72c2f0e7f0f7e54d0d86ebe6eab523a7afb8966ed5240460b99&amp;w=160&amp;u=https%3A%2F%2Fthumborcdn.acast.com%2FaZh0VOUqqVu9MXm-KMje9lKQpMw%3D%2F3000x3000%2Fhttps%3A%2F%2Fstatic.megaphone.fm%2Fpodcasts%2F8dfbdad8-0114-11e8-94c3-63c0986d9a35%2Fimage%2Fuploads_2F1545202886870-0lemrypyyd8-5a09ef6303e950a0ba8ea1be9a7c3aaa_2Flogo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="caption2 singleline">
#           The /Filmcast (AKA The Slashfilmcast)
#          </div>
#          <div class="title singleline">
#           475 - Ant-Man and the Wasp
#          </div>
#          <div class="caption2 singleline">
#           Jul 11, 2018 • 97 min
#          </div>
#         </div>
#        </div>
#       </a>
# ...
#        <img class="art" src="https://overcast.fm/art?s=6ed6bfa962b5c589c6594ee00c9f6036a14ba16ca99581215130ef60a468fd0a&amp;w=160&amp;u=http%3A%2F%2Fstatic.libsyn.com%2Fp%2Fassets%2F2%2Fc%2F6%2F2%2F2c6245d9d4f44433%2Fvector-album-art.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Vector with Rene Ritchie
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1077135613/why-we-fly">
#        <img class="art" src="https://overcast.fm/art?s=e575680613907463bd31a549b224fdb76f5e0475b659d11089b471cd863cc8a5&amp;w=160&amp;u=http%3A%2F%2Fstatic.libsyn.com%2Fp%2Fassets%2F2%2Fd%2F1%2F5%2F2d1510a2b1fa5db0%2FWhy_We_Fly_Cover_Art.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Why We Fly
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/p267921-TrB7N5">
#        <img class="art" src="https://overcast.fm/art?s=3025e28d9cfadfe519fd66ebe0cdcd5da8fc97fe7eb0d617e1ac9ce044f9fc17&amp;w=160&amp;u=https%3A%2F%2Fmedia.npr.org%2Fassets%2Fimg%2F2018%2F08%2F22%2Fsmallerworldstoryofthedaypodcasttile1_sq-b91e694343dfead80e74d063d7afb40788097ec2.jpg%3Fs%3D1400"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           World Story of the Day : NPR
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1233834541/wow-in-the-world">
#        <img class="art" src="https://overcast.fm/art?s=90f018d6d4cad154eb27cbe7b80b540a709f64d8f3b4007ef9210d5c6ac03db1&amp;w=160&amp;u=https%3A%2F%2Fmedia.npr.org%2Fassets%2Fimg%2F2018%2F08%2F06%2Fnpr_witw_podcasttile_sq-2fdc0ec2ec9d937e93684318fcc0b90042db2605.jpg%3Fs%3D1400"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Wow in the World
#          </div>
#         </div>
#        </div>
#       </a>
#       <h2 class="ocseparatorbar">
#        Played Podcasts
#       </h2>
#       <a class="feedcell" href="/itunes1219833877/accelerated-flight-school-podcast">
#        <img class="art" src="https://overcast.fm/art?s=48980fb02656b6a71cd9fe546e73ec7b266c5514b0becc8c22b80847fc347a6c&amp;w=160&amp;u=https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fafsp%2FImages%2Fafsp-cover-art-rgb.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Accelerated Flight School Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes719309884/the-airplane-owners-podcast">
#        <img class="art" src="https://overcast.fm/art?s=54621df5bda782e36731ddd3319407a326a2e23b4cbfd9eca99b27f8ef0976d2&amp;w=160&amp;u=https%3A%2F%2Fmedia.simplecast.com%2Fpodcast%2Fimage%2F1788%2F1457459239-artwork.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           The Airplane Owners Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1208575899/alan-weiss-the-uncomfortable-truth">
#        <img class="art" src="https://overcast.fm/art?s=8f149fa5397eaec4707c8f2dee86b04c38f840a2ee8875dc74fb418cd7e43460&amp;w=160&amp;u=http%3A%2F%2Fi1.sndcdn.com%2Favatars-000303280910-tgldg9-original.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Alan Weiss' The Uncomfortable Truth
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1114239876/alien-minute">
#        <img class="art" src="https://overcast.fm/art?s=642b11231dda5b6a39cc1ee677df0bba15658eed3d5cb0c34769d87001e39800&amp;w=160&amp;u=https%3A%2F%2Fpbcdn1.podbean.com%2Fimglogo%2Fimage-logo%2F1996337%2FArt19Logo.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Alien Minute
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes926057988/alphabeatical">
#        <img class="art" src="https://overcast.fm/art?s=bfacb26b544bd4f1e1c86e63e6475849982f3dea03dcb793c1988f9289f2ce31&amp;w=160&amp;u=http%3A%2F%2Fwww.alphabeatical.com%2Fimages%2FAlphaBeatical_logo_600.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           AlphaBeatical
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1223782070/aviation-news-talk-podcast">
#        <img class="art" src="https://overcast.fm/art?s=4be4e4e6c765565027a2e4a20f38840faf11ae842c4865446ea15478cf752d46&amp;w=160&amp;u=http%3A%2F%2Fstatic.libsyn.com%2Fp%2Fassets%2Fb%2F3%2Fc%2F3%2Fb3c3e1ce0be5cb4e%2FNews_Talk_Album_Headset_art-4_1400.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Aviation News Talk podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes136840269/avweb-podcasts">
#        <img class="art" src="https://overcast.fm/art?s=c0b792a7f54da64e27f493c5e003fd41281e16771238905afad12ca498c2b7ea&amp;w=160&amp;u=https%3A%2F%2Fcdn.avweb.com%2Fmedia%2Fui%2Flogos%2FAVwebA_1400x1400.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           AVweb Podcasts
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1076448558/becoming-a-data-scientist-podcast">
#        <img class="art" src="https://overcast.fm/art?s=cc881c081899f00517c60741e381f0209d7b0838e9beb2b90a6d16a6dcdd129d&amp;w=160&amp;u=https%3A%2F%2Fwww.becomingadatascientist.com%2Fwp-content%2Fuploads%2F2016%2F01%2FBecomingaDataScientistPodcast51.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Becoming A Data Scientist Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/p270291-N6L1yR">
#        <img class="art" src="https://overcast.fm/art?s=ccd1c3b5c45fbeb3733b29fecd064c7b29b9e0b4c087c45453e03e0617f8f2c6&amp;w=160&amp;u=https%3A%2F%2Fmedia.npr.org%2Fassets%2Fimg%2F2018%2F08%2F22%2Fnpr_businessstoryoftheday_podcasttile1_sq-40c12ca8a62225f7c0f46a8db14f32a0ee2f3777.jpg%3Fs%3D1400"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Business Story of the Day : NPR
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1353825724/change-agent">
#        <img class="art" src="https://overcast.fm/art?s=d7db5a074aa65de3596d9a93b8da6af736aeb0890243ac6f8664eb3c82e9abb4&amp;w=160&amp;u=https%3A%2F%2Fcontent.production.cdn.art19.com%2Fimages%2Fdb%2F93%2Fcd%2F2d%2Fdb93cd2d-d5e5-407b-9d2c-ae5386dd531d%2F5837631ce31c66184ebaf7871a2bacb6dcb47bfee6da5e39501563f75cc9dcdad2a989a6b5d56a02342ad2c6e3d70bf8bfeb27ab3fb6b060a3cf8c18dd026ef1.jpeg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Change Agent
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes665964031/clockwise">
#        <img class="art" src="https://overcast.fm/art?s=850c0095406a623040f1436453895edec0c1e76c5612400685523260b7900ff0&amp;w=160&amp;u=http%3A%2F%2Frelayfm.s3.amazonaws.com%2Fuploads%2Fbroadcast%2Fimage%2F12%2Fclockwise_artwork.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Clockwise
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1200361736/the-daily">
#        <img class="art" src="https://overcast.fm/art?s=9a8233fd27d00f64d82a2a1032ff37c720e106d7dbac47e4b178548b65acaebe&amp;w=160&amp;u=https%3A%2F%2Fcontent.production.cdn.art19.com%2Fimages%2F01%2F1b%2Ff3%2Fd6%2F011bf3d6-a448-4533-967b-e2f19e376480%2F7fdd4469c1b5cb3b66aa7dcc9fa21f138efe9a0310a8a269f3dcd07c83a552844fcc445ea2d53db1e55d6fb077aeaa8a1566851f8f2d8ac4349d9d23a87a69f5.jpeg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           The Daily
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1344237371/data-science">
#        <img class="art" src="https://overcast.fm/art?s=5ddc24a1ddd5877d8059367fbd8898c8747db5d6df92648a9441b99cba3dbb61&amp;w=160&amp;u=https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fanchor-generated-image-bank%2Fproduction%2Fpodcast%2F384452%2Fanchor-podcast-5fds2nvqrbg.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Data Science
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes909462080/datascience-la-podcast">
#        <img class="art" src="https://overcast.fm/art?s=616fcae9256224746730b103e5cf90822bb617ff5d47415e7c5e0ae895614a2f&amp;w=160&amp;u=https%3A%2F%2Fassets.podomatic.net%2Fts%2F45%2F67%2F23%2Fearino%2F1400x1400_9854401.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           DataScience.LA Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1339952977/dear-hbr">
#        <img class="art" src="https://overcast.fm/art?s=3eb52c5af9bb1825a9ebae42533e8c95d083e808ff494a88d8f7f3608550f2af&amp;w=160&amp;u=https%3A%2F%2Fhbr.org%2Fresources%2Fimages%2Fpodcasts%2F1400-dear-hbr-lg-2.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Dear HBR:
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes875119779/entreprogrammers-podcast">
#        <img class="art" src="https://overcast.fm/art?s=309418ca1ad548917b30e17cef5a38d3bd70d00f2fb3771db095eeb21711f727&amp;w=160&amp;u=http%3A%2F%2Fstatic.libsyn.com%2Fp%2Fassets%2F3%2Fc%2F1%2F8%2F3c181134ae5e294b%2Fentreprogrammers-cover-art.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Entreprogrammers Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1041003003/flying-and-life-podcast">
#        <img class="art" src="https://overcast.fm/art?s=13b77227e823c73404b9d632c9cf03b0483e664fb3bc3e50ade49e5fb3620229&amp;w=160&amp;u=http%3A%2F%2Fstatic.libsyn.com%2Fp%2Fassets%2F0%2Fb%2F6%2Ff%2F0b6f7e768ffa5067%2FImage.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Flying and Life Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes152022135/hbr-ideacast">
#        <img class="art" src="https://overcast.fm/art?s=9d1fd79773ad6464a3425f44cc1489a1d68b39ade1879207c530ed39dbf9c2fd&amp;w=160&amp;u=https%3A%2F%2Fhbr.org%2Fresources%2Fimages%2Fideacast%2F1400-hbr-ideacast-lg-3.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           HBR IdeaCast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes646702774/history-in-five-minutes-podcast">
#        <img class="art" src="https://overcast.fm/art?s=56681cbd1016b04af92f2e147bfb72576750c43ed457c1429e27fccf81a6b7d9&amp;w=160&amp;u=http%3A%2F%2Fwww.michaelrank.net%2Fwp-content%2Fuploads%2Fpowerpress%2Fpodcastimage1400x1400.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           History in Five Minutes Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes399509351/in-the-pattern-podcast">
#        <img class="art" src="https://overcast.fm/art?s=2eeae87f83a2986ddcb2ea3166e01696a861c7b3b1bfe484ce53622ed733316e&amp;w=160&amp;u=https%3A%2F%2Fmedia.simplecast.com%2Fpodcast%2Fimage%2F144%2F1438745580-artwork.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           In The Pattern Podcast
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1181589165/make-me-smart-with-kai-and-molly">
#        <img class="art" src="https://overcast.fm/art?s=0f8b75445faa60aa3d5a1973e4b5fc9d6cecb6c57757cf1e442e20b8b3019f85&amp;w=160&amp;u=https%3A%2F%2Fimg.apmcdn.org%2F3b52d43387699b5913df1dc0d4a460dcf0dba882%2Fsquare%2Fcc6709-make-me-smart-tile.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Make Me Smart with Kai and Molly
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/p265489-MOVl6n">
#        <img class="art" src="https://overcast.fm/art?s=3cdb11fed9ba45acdf066fa84bacae0cdd2c7751a17a064f2be814e1d9a637e5&amp;w=160&amp;u=https%3A%2F%2Fa.espncdn.com%2Fi%2Fespnradio%2Fpodcast%2FNFLNation%2FNFLNation_1400x1400.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           NFL Nation
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes147232181/pti">
#        <img class="art" src="https://overcast.fm/art?s=9d283862c8044fd55edc37a73e29e3893389551ea4aaeaac9fbbd420c3097765&amp;w=160&amp;u=https%3A%2F%2Fa.espncdn.com%2Fi%2Fespnradio%2Fpodcast%2FPardonTheInterruption%2F1400x1400.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           PTI
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes1173690032/python-bytes">
#        <img class="art" src="https://overcast.fm/art?s=fc4363bec770cedaa0ca558f00bfa19637a18d14482d577ec5eb683a11535243&amp;w=160&amp;u=http%3A%2F%2Fpythonbytes.fm%2Fstatic%2Fimg%2Fpodcast-theme-img_1400.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Python Bytes
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes997930288/robot-or-not">
#        <img class="art" src="https://overcast.fm/art?s=2b64ffe57de94b7679446a543ae8bd337754b8015de630c21794e6cf47302d11&amp;w=160&amp;u=https%3A%2F%2Fwww.theincomparable.com%2Fimgs%2Flogos%2Flogo-robot-3x.jpg%3Fcache-buster%3D2017-06-11"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Robot or Not?
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes979020229/talk-python-to-me-python-conversations-for-passionate-developers">
#        <img class="art" src="https://overcast.fm/art?s=fb829b276774917f6fdb73f4c43408f6cfb25cef3a1a506c1182ebce989df86d&amp;w=160&amp;u=https%3A%2F%2Ftalkpython.fm%2Fstatic%2Fimg%2Fpodcast-theme-img_1400_v3.png"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           Talk Python To Me - Python conversations for passionate developers
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="feedcell" href="/itunes477248343/you-need-a-budget-ynab">
#        <img class="art" src="https://overcast.fm/art?s=6489c3cadd318b303c3fbc70745e6528f0b64b3c08f280104be5d8475dfb87d5&amp;w=160&amp;u=https%3A%2F%2Fssl-static.libsyn.com%2Fp%2Fassets%2Fd%2F4%2Fb%2Fd%2Fd4bd4074f146dba0%2FYNABTree_1400x1400.jpg"/>
#        <div class="cellcontent">
#         <div class="titlestack">
#          <div class="title">
#           You Need A Budget (YNAB)
#          </div>
#         </div>
#        </div>
#       </a>
#      </div>
#      <div class="pure-u-1-5">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="footer l-box is-center">
#    © 2014–2019 Overcast Radio, LLC
#    <br/>
#    <a href="/privacy">
#     Privacy Policy
#    </a>
#    •
#    <a href="/contact">
#     Contact
#    </a>
#    •
#    <a href="/podcasterinfo">
#     Info for Podcasters
#    </a>
#    •
#    <a href="/forecast">
#     Forecast
#    </a>
#   </div>
#  </body>
# </html>

# %% [markdown]
# # Downloading audio
# - use urllib instead of requests

# %%
import urllib

url = 'http://archive-server.liveatc.net/kday/'
kday = 'KDAY'
month = 'Feb'
year = 2019

def download(url, station, month, day, year, time):
    variables = f'-{month}-{day}-{year}-{time}Z.mp3'
    link = url + station + variables
    print(link)
    response = urllib.request.urlopen(link)
    
    with open('{}{}'.format(station, variables), 'wb') as f:
    	f.write(response.read())
                
download(url, kday, month, '10', year, '1800')
# Out:
# http://archive-server.liveatc.net/kday/KDAY-Feb-10-2019-1800Z.mp3

# %% [markdown]
# # Live Coding?!
# - if time allows...

# %%
r = requests.get('https://books.goalkicker.com/')

# %%
soup_program = BeautifulSoup(r.text, 'html.parser')
print(soup_program.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Free Programming Books – GoalKicker.com
#   </title>
#   <meta content="width=800" name="viewport"/>
#   <meta charset="utf-8"/>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://books.goalkicker.com/" rel="canonical"/>
#   <link href="https://fonts.googleapis.com/css?family=Quicksand" rel="stylesheet"/>
#   <meta content="Free Programming Books on Android development, C, C#, CSS, HTML5, iOS development, Java, JavaScript, PowerShell, PHP, Python, SQL Sever and more" name="description">
#    <meta content="Programming Books,Programming PDF Books,Programming Tutorials,Android development,CSS,HTML5,iOS development,Java,JavaScript,PowerShell,PHP,Python,SQL Sever" name="keywords">
#     <meta content="Free Programming Books; HTML5, CSS3, JavaScript, PHP, Python..." property="og:title"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://books.goalkicker.com/goalkicker_books.png" property="og:image"/>
#     <meta content="https://books.goalkicker.com/" property="og:url"/>
#     <style>
#      .grow {
# 	transition: all .3s ease-in-out;
# 	transform: scale(0.9);
# }
#
# .grow:hover, .grow:focus {
# 	transform: scale(1);
# }
#
# .books {
# 	margin: auto;
# 	padding-bottom:50px;
# 	padding-top: 20px;
# }
#
# .bookContainer img {
# 	box-shadow: 0px 0px 18px 0px #666666;
# 	margin-bottom:5px;
# }
#
# body, html {
# 	margin: 0px;
# 	padding: 0px;
# 	border: 0px;
# }
#
# body {
# 	text-align:center;
# 	font-family: 'Quicksand', sans-serif;
# 	background-color: #eeeeee;
# }
#
# h1, h2 {
# 	margin: 0px;
# }
#
# #page {
# 	margin: auto;
# 	padding-left: 10px;
# 	padding-right: 10px;
# 	padding-top: 10px;
# 	padding-bottom: 40px;
# 	background-color: #ffffff;
# 	max-width: 1100px;
# }
#
# .bookContainer {
# 	display: inline-block;
# }
#
# @media screen and (max-width: 800px) {
# 	#footer {
# 		height: 80px;
# 	}
#
# 	#footerBackground {
# 		height: 80px;
# 	}
#
# 	.grow {
# 		transform: scale(0.9);
# 	}
# }
#
# .latest-news {
# 	width: 400px;
# 	margin: auto;
# 	text-align: left;
# }
#
# .latest-news p {
# 	margin-bottom: 0px;
# 	padding-bottom: 0px;
# }
#
# button.signup {
# 	background-color: #3498db;
# 	text-decoration:underline;
# 	color: #ffffff;
# 	border-radius:10px;
# 	width: 200px;
# 	height: 60px;
# 	border: 0px;
# 	cursor: pointer;
# 	transform: scale(0.9);
# 	transition: all .1s ease-in-out;
# 	font-size: 18px;
# 	font-weight: bold;
# }
#
#
# button:hover {
# 	transform: scale(1);
# }
#
# .user-signup input {
#     width: 250px;
#     border: 1px solid #3498db;
#     border-radius: 10px;
#     padding: 10px;
# }
#
# .user-signup th {
# 	text-align: right;
# }
#     </style>
#     <script>
#      function submitForm() {
# 	var nameValue = document.getElementById("name").value;
# 	var emailValue = document.getElementById("email").value;
# 	var http = new XMLHttpRequest();
# 	var url = "../sendEmail.php";
# 	var params = "message=" + encodeURIComponent(nameValue + ":" + emailValue + ":" + window.location);
# 	http.open("POST", url, true);
# 	http.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
# 	http.onreadystatechange = function() {
# 		if (http.readyState == 4 && http.status == 200) {
# 			alert("Success");
# 		}
# 	}
# 	http.send(params);
#
# 	return false;
# }
#     </script>
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-111565129-1">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-111565129-1');
#     </script>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="page">
#    <h1>
#     Programming Notes for Professionals books
#    </h1>
#    <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <!-- Test -->
#    <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#    </ins>
#    <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
#    </script>
#    <div class="books">
#     <div class="bookContainer grow">
#      <a href="DotNETFrameworkBook/" target="_blank">
#       <img alt=".NETFramework book" height="495" src="DotNETFrameworkBook/DotNETFrameworkGrow.png" width="350"/>
#      </a>
#      <br/>
#      .NET Framework Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="AlgorithmsBook/" target="_blank">
#       <img alt="Algorithms book" height="495" src="AlgorithmsBook/AlgorithmsGrow.png" width="350"/>
#      </a>
#      <br/>
#      Algorithms Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="AndroidBook/" target="_blank">
#       <img alt="Android book" height="495" src="AndroidBook/AndroidGrow.png" width="350"/>
#      </a>
#      <br/>
#      AndroidÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="Angular2Book/" target="_blank">
#       <img alt="Angular2 book" height="495" src="Angular2Book/Angular2Grow.png" width="350"/>
#      </a>
#      <br/>
#      Angular 2 Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="AngularJSBook/" target="_blank">
#       <img alt="AngularJS book" height="495" src="AngularJSBook/AngularJSGrow.png" width="350"/>
#      </a>
#      <br/>
#      AngularJS Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="BashBook/" target="_blank">
#       <img alt="Bash book" height="495" src="BashBook/BashGrow.png" width="350"/>
#      </a>
#      <br/>
#      Bash Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="CBook/" target="_blank">
#       <img alt="C book" height="495" src="CBook/CGrow.png" width="350"/>
#      </a>
#      <br/>
#      C Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="CPlusPlusBook/" target="_blank">
#       <img alt="C++ book" height="495" src="CPlusPlusBook/CPlusPlusGrow.png" width="350"/>
#      </a>
#      <br/>
#      C++ Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="CSharpBook/" target="_blank">
#       <img alt="C# book" height="495" src="CSharpBook/CSharpGrow.png" width="350"/>
#      </a>
#      <br/>
#      C# Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="CSSBook/" target="_blank">
#       <img alt="CSS book" height="495" src="CSSBook/CSSGrow.png" width="350"/>
#      </a>
#      <br/>
#      CSS Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="EntityFrameworkBook/" target="_blank">
#       <img alt="Entity Framework book" height="495" src="EntityFrameworkBook/EntityFrameworkGrow.png" width="350"/>
#      </a>
#      <br/>
#      Entity Framework Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="ExcelVBABook/" target="_blank">
#       <img alt="Excel VBA book" height="495" src="ExcelVBABook/ExcelVBAGrow.png" width="350"/>
#      </a>
#      <br/>
#      ExcelÂ® VBA Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="GitBook/" target="_blank">
#       <img alt="Git book" height="495" src="GitBook/GitGrow.png" width="350"/>
#      </a>
#      <br/>
#      GitÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="HaskellBook/" target="_blank">
#       <img alt="Haskell book" height="495" src="HaskellBook/HaskellGrow.png" width="350"/>
#      </a>
#      <br/>
#      Haskell Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="HibernateBook/" target="_blank">
#       <img alt="Hibernate book" height="495" src="HibernateBook/HibernateGrow.png" width="350"/>
#      </a>
#      <br/>
#      Hibernate Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="HTML5Book/" target="_blank">
#       <img alt="HTML5 book" height="495" src="HTML5Book/HTML5Grow.png" width="350"/>
#      </a>
#      <br/>
#      HTML5 Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="HTML5CanvasBook/" target="_blank">
#       <img alt="HTML5 Canvas book" height="495" src="HTML5CanvasBook/HTML5CanvasGrow.png" width="350"/>
#      </a>
#      <br/>
#      HTML5 Canvas Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="iOSBook/" target="_blank">
#       <img alt="iOS book" height="495" src="iOSBook/iOSGrow.png" width="350"/>
#      </a>
#      <br/>
#      iOSÂ® Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="JavaBook/" target="_blank">
#       <img alt="Java book" height="495" src="JavaBook/JavaGrow.png" width="350"/>
#      </a>
#      <br/>
#      JavaÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="JavaScriptBook/" target="_blank">
#       <img alt="JavaScript book" height="495" src="JavaScriptBook/JavaScriptGrow.png" width="350"/>
#      </a>
#      <br/>
#      JavaScriptÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="jQueryBook/" target="_blank">
#       <img alt="jQuery book" height="495" src="jQueryBook/jQueryGrow.png" width="350"/>
#      </a>
#      <br/>
#      jQueryÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="KotlinBook/" target="_blank">
#       <img alt="Kotlin book" height="495" src="KotlinBook/KotlinGrow.png" width="350"/>
#      </a>
#      <br/>
#      KotlinÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="LaTeXBook/" target="_blank">
#       <img alt="LaTeX book" height="495" src="LaTeXBook/LaTeXGrow.png" width="350"/>
#      </a>
#      <br/>
#      LaTeX Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="LinuxBook/" target="_blank">
#       <img alt="Linux book" height="495" src="LinuxBook/LinuxGrow.png" width="350"/>
#      </a>
#      <br/>
#      LinuxÂ® Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="MATLABBook/" target="_blank">
#       <img alt="MATLAB book" height="495" src="MATLABBook/MATLABGrow.png" width="350"/>
#      </a>
#      <br/>
#      MATLABÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="MicrosoftSQLServerBook/" target="_blank">
#       <img alt="Microsoft SQL Server book" height="495" src="MicrosoftSQLServerBook/MicrosoftSQLServerGrow.png" width="350"/>
#      </a>
#      <br/>
#      MicrosoftÂ® SQL ServerÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="MongoDBBook/" target="_blank">
#       <img alt="MongoDB book" height="495" src="MongoDBBook/MongoDBGrow.png" width="350"/>
#      </a>
#      <br/>
#      MongoDBÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="MySQLBook/" target="_blank">
#       <img alt="MySQL book" height="495" src="MySQLBook/MySQLGrow.png" width="350"/>
#      </a>
#      <br/>
#      MySQLÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="NodeJSBook/" target="_blank">
#       <img alt="NodeJS book" height="495" src="NodeJSBook/NodeJSGrow.png" width="350"/>
#      </a>
#      <br/>
#      Node.JSÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="ObjectiveCBook/" target="_blank">
#       <img alt="ObjectiveC book" height="495" src="ObjectiveCBook/ObjectiveCGrow.png" width="350"/>
#      </a>
#      <br/>
#      Objective-CÂ® Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="OracleDatabaseBook/" target="_blank">
#       <img alt="OracleÂ® Database book" height="495" src="OracleDatabaseBook/OracleDatabaseGrow.png" width="350"/>
#      </a>
#      <br/>
#      OracleÂ® Database Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="PerlBook/" target="_blank">
#       <img alt="Perl book" height="495" src="PerlBook/PerlGrow.png" width="350"/>
#      </a>
#      <br/>
#      PerlÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="PHPBook/" target="_blank">
#       <img alt="PHP book" height="495" src="PHPBook/PHPGrow.png" width="350"/>
#      </a>
#      <br/>
#      PHP Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="PostgreSQLBook/" target="_blank">
#       <img alt="PostgreSQL book" height="495" src="PostgreSQLBook/PostgreSQLGrow.png" width="350"/>
#      </a>
#      <br/>
#      PostgreSQLÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="PowerShellBook/" target="_blank">
#       <img alt="PowerShell book" height="495" src="PowerShellBook/PowerShellGrow.png" width="350"/>
#      </a>
#      <br/>
#      PowerShellÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="PythonBook/" target="_blank">
#       <img alt="Python book" height="495" src="PythonBook/PythonGrow.png" width="350"/>
#      </a>
#      <br/>
#      PythonÂ® Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="RBook/" target="_blank">
#       <img alt="R book" height="495" src="RBook/RGrow.png" width="350"/>
#      </a>
#      <br/>
#      R Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="ReactJSBook/" target="_blank">
#       <img alt="React JS book" height="495" src="ReactJSBook/ReactJSGrow.png" width="350"/>
#      </a>
#      <br/>
#      React JS Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="ReactNativeBook/" target="_blank">
#       <img alt="React Native book" height="495" src="ReactNativeBook/ReactNativeGrow.png" width="350"/>
#      </a>
#      <br/>
#      React Native Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="RubyBook/" target="_blank">
#       <img alt="Ruby book" height="495" src="RubyBook/RubyGrow.png" width="350"/>
#      </a>
#      <br/>
#      RubyÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="RubyOnRailsBook/" target="_blank">
#       <img alt="Ruby on Rails book" height="495" src="RubyOnRailsBook/RubyOnRailsGrow.png" width="350"/>
#      </a>
#      <br/>
#      Ruby on RailsÂ® Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="SpringFrameworkBook/" target="_blank">
#       <img alt="Spring Framework book" height="495" src="SpringFrameworkBook/SpringFrameworkGrow.png" width="350"/>
#      </a>
#      <br/>
#      SpringÂ® Framework Notes for Professionals book
#     </div>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <!-- Test -->
#     <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#     </ins>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#     <div class="bookContainer grow">
#      <a href="SQLBook/" target="_blank">
#       <img alt="SQL book" height="495" src="SQLBook/SQLGrow.png" width="350"/>
#      </a>
#      <br/>
#      SQL Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="SwiftBook/" target="_blank">
#       <img alt="Swift book" height="495" src="SwiftBook/SwiftGrow.png" width="350"/>
#      </a>
#      <br/>
#      Swiftâ¢ Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="TypeScriptBook2/" target="_blank">
#       <img alt="TypeScript book" height="495" src="TypeScriptBook/TypeScriptGrow.png" width="350"/>
#      </a>
#      <br/>
#      TypeScript Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="VBABook/" target="_blank">
#       <img alt="VBA book" height="495" src="VBABook/VBAGrow.png" width="350"/>
#      </a>
#      <br/>
#      VBA Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="VisualBasic_NETBook/" target="_blank">
#       <img alt="VisualBasic.NET book" height="495" src="VisualBasic_NETBook/VisualBasic_NETGrow.png" width="350"/>
#      </a>
#      <br/>
#      Visual BasicÂ® .NET Notes for Professionals book
#     </div>
#     <div class="bookContainer grow">
#      <a href="XamarinFormsBook/" target="_blank">
#       <img alt="XamarinForms book" height="495" src="XamarinFormsBook/XamarinFormsGrow.png" width="350"/>
#      </a>
#      <br/>
#      Xamarin.Forms Notes for Professionals book
#     </div>
#     <div class="latest-news">
#      <p>
#       Latest news, books are updated weekly:
#      </p>
#      <ul>
#       <li>
#        July 2018: Minor corrections in some books
#       </li>
#       <li>
#        May 2018: Formatting improvements in books
#       </li>
#       <li>
#        March 2018: Various books updated
#       </li>
#       <li>
#        February 2018: 6 new books added
#       </li>
#       <li>
#        January 2018: 18 new books added
#       </li>
#       <li>
#        December 2017: 24 new books added
#       </li>
#      </ul>
#     </div>
#     <div id="social">
#      <script>
#       reddit_url = 'https://downloads.goalkicker.com/';
# reddit_title = 'Free Programming Books';
# reddit_newwindow = '1';
#      </script>
#      <script src="//www.redditstatic.com/button/button3.js">
#      </script>
#      <script>
#       window.twttr = (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0],
#     t = window.twttr || {};
#   if (d.getElementById(id)) return t;
#   js = d.createElement(s);
#   js.id = id;
#   js.src = "https://platform.twitter.com/widgets.js";
#   fjs.parentNode.insertBefore(js, fjs);
#
#   t._e = [];
#   t.ready = function(f) {
#     t._e.push(f);
#   };
#
#   return t;
# }(document, "script", "twitter-wjs"));
#      </script>
#      <script src="//platform.linkedin.com/in.js" type="text/javascript">
#       lang: en_US
#      </script>
#      <script data-counter="top" data-url="https://downloads.goalkicker.com/" type="IN/Share">
#      </script>
#      <iframe allowtransparency="true" frameborder="0" height="58" scrolling="no" src="https://www.facebook.com/plugins/share_button.php?href=https%3A%2F%2Fbooks.goalkicker.com/&amp;layout=box_count&amp;size=large&amp;mobile_iframe=true&amp;appId=1419253208402557&amp;width=73&amp;height=58" style="border:none;overflow:hidden" width="73">
#      </iframe>
#      <a class="twitter-share-button" data-size="large" href="https://twitter.com/intent/tweet?text=Free Programming Books">
#       Tweet
#      </a>
#      <p class="no-pad">
#       <small>
#        If you found these free programing books useful,
#        <br/>
#        then please share these free programming books ❤
#       </small>
#      </p>
#      <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#      </script>
#      <!-- Test -->
#      <ins class="adsbygoogle" data-ad-client="ca-pub-0641570161571893" data-ad-format="auto" data-ad-slot="7571798105" style="display:block">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div>
#      <form>
#       <h2>
#        Sign up for new free programming books
#       </h2>
#       <table class="user-signup" style="margin:auto;">
#        <tr>
#         <th>
#          Name:
#         </th>
#         <td>
#          <input id="name" type="text"/>
#         </td>
#        </tr>
#        <tr>
#         <th>
#          Email:
#         </th>
#         <td>
#          <input id="email" type="text"/>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#          <button class="signup" onclick="return submitForm()">
#           Sign up
#          </button>
#         </td>
#        </tr>
#       </table>
#      </form>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
for i in soup_program.select('.bookContainer > a'):
    print(i.get('href'))
# Out:
# DotNETFrameworkBook/
# AlgorithmsBook/
# AndroidBook/
# Angular2Book/
# AngularJSBook/
# BashBook/
# CBook/
# CPlusPlusBook/
# CSharpBook/
# CSSBook/
# EntityFrameworkBook/
# ExcelVBABook/
# GitBook/
# HaskellBook/
# HibernateBook/
# HTML5Book/
# HTML5CanvasBook/
# iOSBook/
# JavaBook/
# JavaScriptBook/
# jQueryBook/
# KotlinBook/
# LaTeXBook/
# LinuxBook/
# MATLABBook/
# MicrosoftSQLServerBook/
# MongoDBBook/
# MySQLBook/
# NodeJSBook/
# ObjectiveCBook/
# OracleDatabaseBook/
# PerlBook/
# PHPBook/
# PostgreSQLBook/
# PowerShellBook/
# PythonBook/
# RBook/
# ReactJSBook/
# ReactNativeBook/
# RubyBook/
# RubyOnRailsBook/
# SpringFrameworkBook/
# SQLBook/
# SwiftBook/
# TypeScriptBook2/
# VBABook/
# VisualBasic_NETBook/
# XamarinFormsBook/

# %%
import requests

# r = requests.get('https://learning.oreilly.com/library/view/python-machine-learning/9781786464477/')
r = requests.get('https://learning.oreilly.com/library/view/r-for-data/9781491910382/')
# r = requests.get('https://www.safaribooksonline.com/library/view/python-data-science/9781491912126/')

# %% [markdown]
# # Other Libraries

# %% [markdown]
# - Scrapy
# - Urllib (standard library)
# - Selenium
# - LXML (alternative to BeautifulSoup)
